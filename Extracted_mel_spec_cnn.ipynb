# %% [markdown]
# ### Feature Engineering

# %%
import pandas as pd
import pickle
import numpy as np
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
import keras
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, Activation
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import gc
import librosa
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive')

# %%
tracks = pd.read_csv('tracks.csv')
tracks.columns = tracks.iloc[0]
tracks = tracks.drop([0, 1])
new_cols = tracks.columns.values
new_cols[0] = 'track_id'
tracks.columns = new_cols
tracks = tracks.reset_index(drop=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,5,6,8,12,18,20,21,22,24,33,34,38,39,44,47,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mfcc = pickle.load(open('mel-spec.pkl', 'rb'))
gc.collect()
mfcc[0]
# Out:
# array([[-65.062225, -47.759476, -44.176395, ..., -39.408173, -41.73693 ,
#         -29.414968],
#        [-65.40291 , -52.760864, -49.179825, ..., -16.405546, -16.314037,
#         -17.623047],
#        [-69.48193 , -56.67646 , -50.5069  , ..., -16.358839, -16.07241 ,
#         -18.654762],
#        ...,
#        [-79.42308 , -59.74297 , -36.38287 , ..., -46.371128, -42.364655,
#         -50.543457],
#        [-80.      , -63.4197  , -41.733234, ..., -50.3838  , -46.90663 ,
#         -58.020092],
#        [-80.      , -73.82068 , -52.945995, ..., -63.188034, -56.469955,
#         -67.65623 ]], dtype=float32)

# %%
mfcc[0].shape
# Out:
# (128, 646)

# %%
mfcc_df = pd.DataFrame(mfcc)
index_nan = np.argwhere(pd.isnull(mfcc))

# %%
mfcc_df = mfcc_df.dropna()
mfcc = mfcc_df.to_numpy().ravel()

max_dim = 0
for i in mfcc:
    if i.shape[1] > max_dim:
        max_dim = i.shape[1]
    else:
        pass
print(max_dim)
# Out:
# 647

# %%
for i in range(len(mfcc)):
    mfcc[i] = np.append(mfcc[i], np.zeros((128, max_dim - mfcc[i].shape[1])), axis=1)
    mfcc[i] = mfcc[i][:128, :400]
    mfcc[i] = librosa.util.normalize(mfcc[i])
    
index_nan = index_nan.ravel()

# %%
mfcc[4].shape
# Out:
# (128, 400)

# %%
del mfcc_df

# %%
gc.collect()
# Out:
# 0

# %%
tracks = tracks.loc[tracks['subset'] == 'small']
tracks = tracks.reset_index()
tracks = tracks.drop(index_nan)
tracks = tracks.reset_index()

# %%
y_train = tracks.loc[(tracks['split'] == 'training')]['genre_top']
y_val = tracks.loc[(tracks['split'] == 'validation')]['genre_top']
y_test = tracks.loc[(tracks['split'] == 'test')]['genre_top']

# %%
index_train = y_train.index
index_val = y_val.index
index_test = y_test.index
print(index_train)
print(index_val)
print(index_test)
# Out:
# Int64Index([   0,    1,    2,    3,    4,    7,    8,    9,   10,   11,
#             ...
#             7981, 7982, 7983, 7984, 7985, 7986, 7987, 7994, 7995, 7996],
#            dtype='int64', length=6397)
# Int64Index([   5,   23,   28,   36,   58,   70,  117,  122,  126,  127,
#             ...
#             7854, 7855, 7856, 7857, 7858, 7859, 7860, 7869, 7871, 7928],
#            dtype='int64', length=800)
# Int64Index([   6,   39,   40,   41,   42,   43,   44,   55,   56,   64,
#             ...
#             7951, 7952, 7964, 7965, 7988, 7989, 7990, 7991, 7992, 7993],
#            dtype='int64', length=800)

# %%
len(y_train) + len(y_val) + len(y_test)
# Out:
# 7997

# %%
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_val = le.transform(y_val)
y_test = le.transform(y_test)

y_train = tf.keras.utils.to_categorical(y_train, num_classes=8, dtype='int32')
y_val = tf.keras.utils.to_categorical(y_val, num_classes=8, dtype='int32')
y_test = tf.keras.utils.to_categorical(y_test, num_classes=8, dtype='int32')

gc.collect()
# Out:
# 0

# %%
mfcc = np.stack(mfcc.ravel()).reshape((-1, 128, 400))
gc.collect()
# Out:
# 0

# %%
mfcc.shape
# Out:
# (7997, 128, 400)

# %%
mfcc = mfcc.reshape((-1, 128, 400, 1))
mfcc.shape
# Out:
# (7997, 128, 400, 1)

# %%
mfcc[0].shape
# Out:
# (128, 400, 1)

# %%
X_train = mfcc[index_train]
X_val = mfcc[index_val]
X_test = mfcc[index_test]

# %%
len(X_train)
# Out:
# 6397

# %%
y_train.shape
# Out:
# (6397, 8)

# %%
X_train[0]
# Out:
# array([[[-0.81327782],
#         [-0.64696609],
#         [-0.81883592],
#         ...,
#         [-0.40507106],
#         [-0.42502928],
#         [-0.45188894]],
#
#        [[-0.81753635],
#         [-0.7147166 ],
#         [-0.91157748],
#         ...,
#         [-0.2125068 ],
#         [-0.21104746],
#         [-0.26406962]],
#
#        [[-0.86852417],
#         [-0.76775859],
#         [-0.93617563],
#         ...,
#         [-0.19474493],
#         [-0.19549944],
#         [-0.27820868]],
#
#        ...,
#
#        [[-0.99278851],
#         [-0.80929857],
#         [-0.67437826],
#         ...,
#         [-0.80659521],
#         [-0.74935479],
#         [-0.73209325]],
#
#        [[-1.        ],
#         [-0.85910482],
#         [-0.77355047],
#         ...,
#         [-0.84994637],
#         [-0.84315453],
#         [-0.79236651]],
#
#        [[-1.        ],
#         [-1.        ],
#         [-0.9813857 ],
#         ...,
#         [-1.        ],
#         [-1.        ],
#         [-1.        ]]])

# %% [markdown]
# ### Experiments (Multiple CNN architectures with DataGenerator in some)

# %%
activation='relu'
optimizer = keras.optimizers.Adam(lr=0.0001)
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(32, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation, input_shape=(128, 400, 1)))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Conv2D(32, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2(), activation=activation))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=1)
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, verbose=1, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Train on 6397 samples, validate on 800 samples
# Epoch 1/50
# 6397/6397 [==============================] - 6s 983us/step - loss: 2.5294 - categorical_accuracy: 0.1498 - val_loss: 2.4412 - val_categorical_accuracy: 0.1925
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.19250, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 2/50
# 6397/6397 [==============================] - 6s 953us/step - loss: 2.3503 - categorical_accuracy: 0.2290 - val_loss: 2.2259 - val_categorical_accuracy: 0.3675
#
# Epoch 00002: val_categorical_accuracy improved from 0.19250 to 0.36750, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 3/50
# 6397/6397 [==============================] - 6s 948us/step - loss: 2.1761 - categorical_accuracy: 0.3039 - val_loss: 2.0765 - val_categorical_accuracy: 0.3988
#
# Epoch 00003: val_categorical_accuracy improved from 0.36750 to 0.39875, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 4/50
# 6397/6397 [==============================] - 6s 948us/step - loss: 2.0687 - categorical_accuracy: 0.3423 - val_loss: 2.0228 - val_categorical_accuracy: 0.3250
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.39875
# Epoch 5/50
# 6397/6397 [==============================] - 6s 947us/step - loss: 2.0103 - categorical_accuracy: 0.3661 - val_loss: 1.9862 - val_categorical_accuracy: 0.3638
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.39875
# Epoch 6/50
# 6397/6397 [==============================] - 6s 952us/step - loss: 1.9624 - categorical_accuracy: 0.3769 - val_loss: 1.9295 - val_categorical_accuracy: 0.4137
#
# Epoch 00006: val_categorical_accuracy improved from 0.39875 to 0.41375, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 7/50
# 6397/6397 [==============================] - 6s 946us/step - loss: 1.9314 - categorical_accuracy: 0.3827 - val_loss: 1.8899 - val_categorical_accuracy: 0.4075
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.41375
# Epoch 8/50
# 6397/6397 [==============================] - 6s 950us/step - loss: 1.9064 - categorical_accuracy: 0.3950 - val_loss: 1.8548 - val_categorical_accuracy: 0.4150
#
# Epoch 00008: val_categorical_accuracy improved from 0.41375 to 0.41500, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 9/50
# 6397/6397 [==============================] - 6s 952us/step - loss: 1.8798 - categorical_accuracy: 0.3960 - val_loss: 1.8298 - val_categorical_accuracy: 0.4300
#
# Epoch 00009: val_categorical_accuracy improved from 0.41500 to 0.43000, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 10/50
# 6397/6397 [==============================] - 6s 950us/step - loss: 1.8603 - categorical_accuracy: 0.4043 - val_loss: 1.8047 - val_categorical_accuracy: 0.4400
#
# Epoch 00010: val_categorical_accuracy improved from 0.43000 to 0.44000, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 11/50
# 6397/6397 [==============================] - 6s 949us/step - loss: 1.8373 - categorical_accuracy: 0.4118 - val_loss: 1.7979 - val_categorical_accuracy: 0.4487
#
# Epoch 00011: val_categorical_accuracy improved from 0.44000 to 0.44875, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 12/50
# 6397/6397 [==============================] - 6s 953us/step - loss: 1.8235 - categorical_accuracy: 0.4096 - val_loss: 1.7717 - val_categorical_accuracy: 0.4462
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.44875
# Epoch 13/50
# 6397/6397 [==============================] - 6s 950us/step - loss: 1.8016 - categorical_accuracy: 0.4244 - val_loss: 1.7685 - val_categorical_accuracy: 0.4375
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.44875
# Epoch 14/50
# 6397/6397 [==============================] - 6s 958us/step - loss: 1.7948 - categorical_accuracy: 0.4222 - val_loss: 1.7763 - val_categorical_accuracy: 0.4525
#
# Epoch 00014: val_categorical_accuracy improved from 0.44875 to 0.45250, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 15/50
# 6397/6397 [==============================] - 6s 984us/step - loss: 1.7743 - categorical_accuracy: 0.4243 - val_loss: 1.7565 - val_categorical_accuracy: 0.4450
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.45250
# Epoch 16/50
# 6397/6397 [==============================] - 6s 950us/step - loss: 1.7666 - categorical_accuracy: 0.4299 - val_loss: 1.7186 - val_categorical_accuracy: 0.4625
#
# Epoch 00016: val_categorical_accuracy improved from 0.45250 to 0.46250, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 17/50
# 6397/6397 [==============================] - 6s 948us/step - loss: 1.7578 - categorical_accuracy: 0.4313 - val_loss: 1.7166 - val_categorical_accuracy: 0.4538
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.46250
# Epoch 18/50
# 6397/6397 [==============================] - 6s 950us/step - loss: 1.7511 - categorical_accuracy: 0.4372 - val_loss: 1.7200 - val_categorical_accuracy: 0.4550
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.46250
# Epoch 19/50
# 6397/6397 [==============================] - 6s 948us/step - loss: 1.7371 - categorical_accuracy: 0.4366 - val_loss: 1.7244 - val_categorical_accuracy: 0.4600
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.46250
# Epoch 20/50
# 6397/6397 [==============================] - 6s 954us/step - loss: 1.7247 - categorical_accuracy: 0.4391 - val_loss: 1.6947 - val_categorical_accuracy: 0.4762
#
# Epoch 00020: val_categorical_accuracy improved from 0.46250 to 0.47625, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 21/50
# 6397/6397 [==============================] - 6s 946us/step - loss: 1.7134 - categorical_accuracy: 0.4454 - val_loss: 1.6804 - val_categorical_accuracy: 0.4675
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.47625
# Epoch 22/50
# 6397/6397 [==============================] - 6s 950us/step - loss: 1.7153 - categorical_accuracy: 0.4496 - val_loss: 1.6950 - val_categorical_accuracy: 0.4775
#
# Epoch 00022: val_categorical_accuracy improved from 0.47625 to 0.47750, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 23/50
# 6397/6397 [==============================] - 6s 952us/step - loss: 1.7088 - categorical_accuracy: 0.4486 - val_loss: 1.6817 - val_categorical_accuracy: 0.4837
#
# Epoch 00023: val_categorical_accuracy improved from 0.47750 to 0.48375, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 24/50
# 6397/6397 [==============================] - 6s 957us/step - loss: 1.6956 - categorical_accuracy: 0.4541 - val_loss: 1.6839 - val_categorical_accuracy: 0.4675
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.48375
# Epoch 25/50
# 6397/6397 [==============================] - 6s 968us/step - loss: 1.6888 - categorical_accuracy: 0.4604 - val_loss: 1.6580 - val_categorical_accuracy: 0.4775
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.48375
# Epoch 26/50
# 6397/6397 [==============================] - 6s 948us/step - loss: 1.6802 - categorical_accuracy: 0.4647 - val_loss: 1.6680 - val_categorical_accuracy: 0.4712
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.48375
# Epoch 27/50
# 6397/6397 [==============================] - 6s 946us/step - loss: 1.6750 - categorical_accuracy: 0.4604 - val_loss: 1.6586 - val_categorical_accuracy: 0.4525
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.48375
# Epoch 28/50
# 6397/6397 [==============================] - 6s 949us/step - loss: 1.6730 - categorical_accuracy: 0.4665 - val_loss: 1.6497 - val_categorical_accuracy: 0.4762
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.48375
# Epoch 29/50
# 6397/6397 [==============================] - 6s 944us/step - loss: 1.6600 - categorical_accuracy: 0.4641 - val_loss: 1.6503 - val_categorical_accuracy: 0.4600
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.48375
# Epoch 30/50
# 6397/6397 [==============================] - 6s 944us/step - loss: 1.6537 - categorical_accuracy: 0.4715 - val_loss: 1.6411 - val_categorical_accuracy: 0.4725
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.48375
# Epoch 31/50
# 6397/6397 [==============================] - 6s 943us/step - loss: 1.6491 - categorical_accuracy: 0.4754 - val_loss: 1.6300 - val_categorical_accuracy: 0.4787
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.48375
# Epoch 32/50
# 6397/6397 [==============================] - 6s 947us/step - loss: 1.6450 - categorical_accuracy: 0.4748 - val_loss: 1.6427 - val_categorical_accuracy: 0.4750
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.48375
# Epoch 33/50
# 6397/6397 [==============================] - 6s 954us/step - loss: 1.6381 - categorical_accuracy: 0.4735 - val_loss: 1.6241 - val_categorical_accuracy: 0.4925
#
# Epoch 00033: val_categorical_accuracy improved from 0.48375 to 0.49250, saving model to best_model_cnn_mel-spec.hdf5
# Epoch 34/50
# 6397/6397 [==============================] - 6s 952us/step - loss: 1.6344 - categorical_accuracy: 0.4752 - val_loss: 1.6351 - val_categorical_accuracy: 0.4825
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.49250
# Epoch 35/50
# 6397/6397 [==============================] - 6s 946us/step - loss: 1.6287 - categorical_accuracy: 0.4768 - val_loss: 1.6468 - val_categorical_accuracy: 0.4563
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.49250
# Epoch 36/50
# 6397/6397 [==============================] - 6s 940us/step - loss: 1.6260 - categorical_accuracy: 0.4744 - val_loss: 1.6180 - val_categorical_accuracy: 0.4775
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.49250
# Epoch 37/50
# 6397/6397 [==============================] - 6s 945us/step - loss: 1.6194 - categorical_accuracy: 0.4779 - val_loss: 1.6187 - val_categorical_accuracy: 0.4675
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.49250
# Epoch 38/50
# 6397/6397 [==============================] - 6s 952us/step - loss: 1.6150 - categorical_accuracy: 0.4798 - val_loss: 1.6090 - val_categorical_accuracy: 0.4700
#
# Epoch 00038: val_categorical_accuracy did not improve from 0.49250
# Epoch 39/50
# 6397/6397 [==============================] - 6s 946us/step - loss: 1.6113 - categorical_accuracy: 0.4863 - val_loss: 1.6058 - val_categorical_accuracy: 0.4750
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.49250
# Epoch 40/50
# 6397/6397 [==============================] - 6s 943us/step - loss: 1.6022 - categorical_accuracy: 0.4834 - val_loss: 1.6072 - val_categorical_accuracy: 0.4850
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.49250
# Epoch 41/50
# 6397/6397 [==============================] - 6s 948us/step - loss: 1.6001 - categorical_accuracy: 0.4880 - val_loss: 1.5987 - val_categorical_accuracy: 0.4762
#
# Epoch 00041: val_categorical_accuracy did not improve from 0.49250
# Epoch 42/50
# 6397/6397 [==============================] - 6s 945us/step - loss: 1.5920 - categorical_accuracy: 0.4866 - val_loss: 1.6105 - val_categorical_accuracy: 0.4888
#
# Epoch 00042: val_categorical_accuracy did not improve from 0.49250
# Epoch 43/50
# 6397/6397 [==============================] - 6s 945us/step - loss: 1.5994 - categorical_accuracy: 0.4860 - val_loss: 1.5901 - val_categorical_accuracy: 0.4787
#
# Epoch 00043: val_categorical_accuracy did not improve from 0.49250
# Epoch 44/50
# 6397/6397 [==============================] - 6s 946us/step - loss: 1.5854 - categorical_accuracy: 0.4905 - val_loss: 1.6180 - val_categorical_accuracy: 0.4725
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.49250
# Epoch 45/50
# 6397/6397 [==============================] - 6s 942us/step - loss: 1.5816 - categorical_accuracy: 0.4934 - val_loss: 1.5906 - val_categorical_accuracy: 0.4787
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.49250
# Epoch 46/50
# 6397/6397 [==============================] - 6s 948us/step - loss: 1.5791 - categorical_accuracy: 0.4916 - val_loss: 1.5932 - val_categorical_accuracy: 0.4775
#
# Epoch 00046: val_categorical_accuracy did not improve from 0.49250
# Epoch 47/50
# 6397/6397 [==============================] - 6s 950us/step - loss: 1.5718 - categorical_accuracy: 0.4970 - val_loss: 1.6061 - val_categorical_accuracy: 0.4550
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.49250
# Epoch 48/50
# 6397/6397 [==============================] - 6s 946us/step - loss: 1.5691 - categorical_accuracy: 0.4963 - val_loss: 1.6301 - val_categorical_accuracy: 0.4450
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.49250
# Epoch 49/50
# 6397/6397 [==============================] - 6s 943us/step - loss: 1.5641 - categorical_accuracy: 0.5026 - val_loss: 1.6096 - val_categorical_accuracy: 0.4700
#
# Epoch 00049: val_categorical_accuracy did not improve from 0.49250
# Epoch 50/50
# 6397/6397 [==============================] - 6s 944us/step - loss: 1.5644 - categorical_accuracy: 0.4924 - val_loss: 1.5788 - val_categorical_accuracy: 0.4712
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.49250
# Train:
# [1.6042659314736847, 0.48413318395614624]
# Val:
# [1.624135503768921, 0.4925000071525574]

# %%
from sklearn.metrics import classification_report

model = load_model('best_model_cnn_mel-spec.hdf5')
X_test_RGB = X_test.reshape((-1, 128, 400))
X_test_RGB = X_test_RGB.reshape((-1, 128, 400, 1))
#X_test_RGB = np.repeat(X_test_RGB[..., np.newaxis], 3, -1)
y_pred = model.predict(X_test_RGB)
y_pred = np.argmax(y_pred, 1)

y_pred = le.inverse_transform(y_pred)
y_true_test = np.argmax(y_test, 1)
y_true_test = le.inverse_transform(y_true_test)

print(classification_report(y_true_test, y_pred))
# Out:
#                precision    recall  f1-score   support
#
#    Electronic       0.40      0.26      0.32       100
#  Experimental       0.22      0.26      0.24       100
#          Folk       0.15      0.19      0.17       100
#       Hip-Hop       0.49      0.74      0.59       100
#  Instrumental       0.34      0.31      0.33       100
# International       0.39      0.21      0.27       100
#           Pop       0.34      0.20      0.25       100
#          Rock       0.51      0.70      0.59       100
#
#      accuracy                           0.36       800
#     macro avg       0.36      0.36      0.34       800
#  weighted avg       0.36      0.36      0.34       800

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

mat = confusion_matrix(y_true_test, y_pred)
plt.figure(figsize=(10,10))

dict_genres = {'Electronic': 0, 'Experimental': 1, 'Folk': 2, 'Hip-Hop': 3, 'Instrumental': 4, 'International': 5, 'Pop': 6, 'Rock': 7}

sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            cmap=sns.cubehelix_palette(8, start=.5, rot=-.75),
            xticklabels=dict_genres.keys(),
            yticklabels=dict_genres.keys())
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# Text(76.2, 0.5, 'predicted label')

# %%
activation='relu'
optimizer = keras.optimizers.Adam(lr=0.0001)
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(16, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation, input_shape=(128, 400, 1)))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Conv2D(16, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2(), activation=activation))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, verbose=0, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Train:
# [1.4268462185712836, 0.5580741167068481]
# Val:
# [1.6007030725479126, 0.4449999928474426]

# %%
activation='relu'
optimizer = keras.optimizers.Adam(lr=0.0001)
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(16, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation, input_shape=(128, 400, 1)))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Conv2D(16, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2(), activation=activation))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(X_train, y_train, validation_split=0.1, epochs=100, verbose=0, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Train:
# [1.406803765147109, 0.5713616013526917]
# Val:
# [1.6085491228103637, 0.45875000953674316]

# %%
activation='relu'
optimizer = keras.optimizers.Adam(lr=0.0001)
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(64, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation, input_shape=(128, max_dim, 1)))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Conv2D(64, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2(), activation=activation))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(X_train, y_train, validation_split=0.1, epochs=100, verbose=0, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Train:
# [1.384960632725248, 0.5944974422454834]
# Val:
# [1.641326379776001, 0.45124998688697815]

# %%
activation='relu'
optimizer = keras.optimizers.Adam(lr=0.0001)
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(64, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation, input_shape=(128, max_dim, 1)))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dropout(0.5))
model.add(Conv2D(64, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dropout(0.5))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2(), activation=activation))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(X_train, y_train, validation_split=0.1, epochs=100, verbose=0, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Train:
# [1.2937339757110098, 0.6137251853942871]
# Val:
# [1.6071334314346313, 0.4712499976158142]

# %%
activation='relu'
optimizer = keras.optimizers.Adam()
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(16, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation, input_shape=(128, max_dim, 1)))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dropout(0.5))
model.add(Conv2D(16, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dropout(0.5))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2(), activation=activation))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(X_train, y_train, validation_split=0.1, epochs=100, verbose=0, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Train:
# [1.1999250490515982, 0.630608081817627]
# Val:
# [1.6504947710037232, 0.4449999928474426]

# %%
activation='relu'
optimizer = keras.optimizers.Adam()
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(16, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation, input_shape=(128, 400, 1)))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dropout(0.5))
model.add(Conv2D(16, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dropout(0.5))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2(), activation=activation))
model.add(Flatten())
#model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(X_train, y_train, validation_split=0.1, epochs=100, verbose=0, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Train:
# [1.2742456230350225, 0.5915272831916809]
# Val:
# [1.7173402500152588, 0.45875000953674316]

# %%
from keras.layers import SpatialDropout2D

activation='relu'
optimizer = keras.optimizers.Adam()
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(16, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation, input_shape=(128, max_dim, 1)))
model.add(SpatialDropout2D(0.5))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Conv2D(16, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation))
model.add(SpatialDropout2D(0.5))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2(), activation=activation))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(X_train, y_train, validation_split=0.1, epochs=100, verbose=0, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Train:
# [1.589223384279487, 0.4758480489253998]
# Val:
# [1.82178560256958, 0.32624998688697815]

# %%
activation='relu'
optimizer = keras.optimizers.Adam(lr=0.001)
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(32, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation, input_shape=(128, max_dim, 1)))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dropout(0.5))
model.add(Conv2D(32, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dropout(0.5))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2(), activation=activation))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(X_train, y_train, validation_split=0.1, epochs=50, verbose=1, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Train:
# [1.3203800516760646, 0.5865249037742615]
# Val:
# [1.5341482257843018, 0.4650000035762787]

# %%
activation='relu'
optimizer = keras.optimizers.Adam(lr=0.001)
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(32, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation, input_shape=(128, max_dim, 1)))
model.add(SpatialDropout2D(0.5))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Conv2D(32, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation))
model.add(SpatialDropout2D(0.5))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2(), activation=activation))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(X_train, y_train, validation_split=0.1, epochs=100, verbose=1, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Train on 5757 samples, validate on 640 samples
# Epoch 1/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 2.3602 - categorical_accuracy: 0.1503 - val_loss: 2.2296 - val_categorical_accuracy: 0.1703
# Epoch 2/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 2.1452 - categorical_accuracy: 0.1994 - val_loss: 2.0417 - val_categorical_accuracy: 0.2812
# Epoch 3/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 2.0365 - categorical_accuracy: 0.2430 - val_loss: 1.9332 - val_categorical_accuracy: 0.3594
# Epoch 4/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.9772 - categorical_accuracy: 0.2644 - val_loss: 1.8280 - val_categorical_accuracy: 0.3703
# Epoch 5/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.9594 - categorical_accuracy: 0.2774 - val_loss: 1.8523 - val_categorical_accuracy: 0.3938
# Epoch 6/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.9377 - categorical_accuracy: 0.2845 - val_loss: 1.8565 - val_categorical_accuracy: 0.3422
# Epoch 7/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.9192 - categorical_accuracy: 0.2892 - val_loss: 1.8723 - val_categorical_accuracy: 0.3422
# Epoch 8/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.9193 - categorical_accuracy: 0.2986 - val_loss: 1.8516 - val_categorical_accuracy: 0.3203
# Epoch 9/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.9061 - categorical_accuracy: 0.2925 - val_loss: 1.8044 - val_categorical_accuracy: 0.3859
# Epoch 10/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8960 - categorical_accuracy: 0.3062 - val_loss: 1.8304 - val_categorical_accuracy: 0.3859
# Epoch 11/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8856 - categorical_accuracy: 0.3146 - val_loss: 1.8149 - val_categorical_accuracy: 0.3406
# Epoch 12/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8954 - categorical_accuracy: 0.3078 - val_loss: 1.7628 - val_categorical_accuracy: 0.4125
# Epoch 13/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8660 - categorical_accuracy: 0.3286 - val_loss: 1.7570 - val_categorical_accuracy: 0.4000
# Epoch 14/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8730 - categorical_accuracy: 0.3177 - val_loss: 1.7864 - val_categorical_accuracy: 0.3797
# Epoch 15/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8713 - categorical_accuracy: 0.3234 - val_loss: 1.7692 - val_categorical_accuracy: 0.3734
# Epoch 16/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8577 - categorical_accuracy: 0.3309 - val_loss: 1.8491 - val_categorical_accuracy: 0.3203
# Epoch 17/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8719 - categorical_accuracy: 0.3123 - val_loss: 1.7853 - val_categorical_accuracy: 0.3797
# Epoch 18/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8486 - categorical_accuracy: 0.3319 - val_loss: 1.7578 - val_categorical_accuracy: 0.4078
# Epoch 19/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8497 - categorical_accuracy: 0.3321 - val_loss: 1.7873 - val_categorical_accuracy: 0.3500
# Epoch 20/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8447 - categorical_accuracy: 0.3339 - val_loss: 1.8361 - val_categorical_accuracy: 0.3422
# Epoch 21/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8434 - categorical_accuracy: 0.3337 - val_loss: 1.7402 - val_categorical_accuracy: 0.4109
# Epoch 22/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8185 - categorical_accuracy: 0.3432 - val_loss: 1.7705 - val_categorical_accuracy: 0.3750
# Epoch 23/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8126 - categorical_accuracy: 0.3531 - val_loss: 1.7259 - val_categorical_accuracy: 0.4234
# Epoch 24/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8137 - categorical_accuracy: 0.3505 - val_loss: 1.7218 - val_categorical_accuracy: 0.3984
# Epoch 25/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8147 - categorical_accuracy: 0.3445 - val_loss: 1.7000 - val_categorical_accuracy: 0.4297
# Epoch 26/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8159 - categorical_accuracy: 0.3413 - val_loss: 1.7248 - val_categorical_accuracy: 0.4125
# Epoch 27/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.8057 - categorical_accuracy: 0.3528 - val_loss: 1.7410 - val_categorical_accuracy: 0.4016
# Epoch 28/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7945 - categorical_accuracy: 0.3594 - val_loss: 1.7095 - val_categorical_accuracy: 0.4156
# Epoch 29/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7813 - categorical_accuracy: 0.3613 - val_loss: 1.7469 - val_categorical_accuracy: 0.3875
# Epoch 30/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7979 - categorical_accuracy: 0.3570 - val_loss: 1.7651 - val_categorical_accuracy: 0.3844
# Epoch 31/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7802 - categorical_accuracy: 0.3688 - val_loss: 1.7026 - val_categorical_accuracy: 0.4109
# Epoch 32/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7797 - categorical_accuracy: 0.3705 - val_loss: 1.7789 - val_categorical_accuracy: 0.3703
# Epoch 33/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7790 - categorical_accuracy: 0.3603 - val_loss: 1.7420 - val_categorical_accuracy: 0.3844
# Epoch 34/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7701 - categorical_accuracy: 0.3688 - val_loss: 1.7507 - val_categorical_accuracy: 0.3781
# Epoch 35/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7746 - categorical_accuracy: 0.3682 - val_loss: 1.7505 - val_categorical_accuracy: 0.3953
# Epoch 36/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7508 - categorical_accuracy: 0.3748 - val_loss: 1.7471 - val_categorical_accuracy: 0.3938
# Epoch 37/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7524 - categorical_accuracy: 0.3801 - val_loss: 1.6997 - val_categorical_accuracy: 0.4406
# Epoch 38/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7549 - categorical_accuracy: 0.3733 - val_loss: 1.7470 - val_categorical_accuracy: 0.3875
# Epoch 39/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7399 - categorical_accuracy: 0.3865 - val_loss: 1.7196 - val_categorical_accuracy: 0.4094
# Epoch 40/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7384 - categorical_accuracy: 0.3940 - val_loss: 1.7667 - val_categorical_accuracy: 0.3891
# Epoch 41/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7372 - categorical_accuracy: 0.3846 - val_loss: 1.7468 - val_categorical_accuracy: 0.4187
# Epoch 42/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7411 - categorical_accuracy: 0.3802 - val_loss: 1.7696 - val_categorical_accuracy: 0.3922
# Epoch 43/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7301 - categorical_accuracy: 0.3839 - val_loss: 1.7397 - val_categorical_accuracy: 0.4094
# Epoch 44/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7231 - categorical_accuracy: 0.4002 - val_loss: 1.7324 - val_categorical_accuracy: 0.4234
# Epoch 45/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7251 - categorical_accuracy: 0.3938 - val_loss: 1.7455 - val_categorical_accuracy: 0.3844
# Epoch 46/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7181 - categorical_accuracy: 0.3967 - val_loss: 1.7673 - val_categorical_accuracy: 0.3734
# Epoch 47/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7038 - categorical_accuracy: 0.3992 - val_loss: 1.7747 - val_categorical_accuracy: 0.3828
# Epoch 48/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7057 - categorical_accuracy: 0.4070 - val_loss: 1.7318 - val_categorical_accuracy: 0.4047
# Epoch 49/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7113 - categorical_accuracy: 0.3995 - val_loss: 1.7809 - val_categorical_accuracy: 0.3969
# Epoch 50/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.7105 - categorical_accuracy: 0.3988 - val_loss: 1.7917 - val_categorical_accuracy: 0.3906
# Epoch 51/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6935 - categorical_accuracy: 0.4085 - val_loss: 1.7561 - val_categorical_accuracy: 0.4109
# Epoch 52/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6942 - categorical_accuracy: 0.4018 - val_loss: 1.7482 - val_categorical_accuracy: 0.3938
# Epoch 53/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6913 - categorical_accuracy: 0.4042 - val_loss: 1.7735 - val_categorical_accuracy: 0.3719
# Epoch 54/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6778 - categorical_accuracy: 0.4127 - val_loss: 1.7856 - val_categorical_accuracy: 0.3719
# Epoch 55/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6964 - categorical_accuracy: 0.4061 - val_loss: 1.7782 - val_categorical_accuracy: 0.3656
# Epoch 56/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6887 - categorical_accuracy: 0.4148 - val_loss: 1.7645 - val_categorical_accuracy: 0.3859
# Epoch 57/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6823 - categorical_accuracy: 0.4120 - val_loss: 1.7726 - val_categorical_accuracy: 0.3969
# Epoch 58/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6956 - categorical_accuracy: 0.4014 - val_loss: 1.7575 - val_categorical_accuracy: 0.3875
# Epoch 59/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6667 - categorical_accuracy: 0.4235 - val_loss: 1.7985 - val_categorical_accuracy: 0.3734
# Epoch 60/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6650 - categorical_accuracy: 0.4155 - val_loss: 1.7440 - val_categorical_accuracy: 0.4234
# Epoch 61/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6719 - categorical_accuracy: 0.4211 - val_loss: 1.7702 - val_categorical_accuracy: 0.3797
# Epoch 62/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6696 - categorical_accuracy: 0.4207 - val_loss: 1.7870 - val_categorical_accuracy: 0.3859
# Epoch 63/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6573 - categorical_accuracy: 0.4247 - val_loss: 1.7858 - val_categorical_accuracy: 0.4016
# Epoch 64/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6610 - categorical_accuracy: 0.4303 - val_loss: 1.7685 - val_categorical_accuracy: 0.3750
# Epoch 65/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6645 - categorical_accuracy: 0.4294 - val_loss: 1.7855 - val_categorical_accuracy: 0.3766
# Epoch 66/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6608 - categorical_accuracy: 0.4200 - val_loss: 1.7715 - val_categorical_accuracy: 0.3906
# Epoch 67/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6484 - categorical_accuracy: 0.4290 - val_loss: 1.7915 - val_categorical_accuracy: 0.3859
# Epoch 68/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6624 - categorical_accuracy: 0.4282 - val_loss: 1.8054 - val_categorical_accuracy: 0.3938
# Epoch 69/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6489 - categorical_accuracy: 0.4358 - val_loss: 1.7911 - val_categorical_accuracy: 0.3875
# Epoch 70/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6369 - categorical_accuracy: 0.4377 - val_loss: 1.7751 - val_categorical_accuracy: 0.4000
# Epoch 71/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6469 - categorical_accuracy: 0.4320 - val_loss: 1.7853 - val_categorical_accuracy: 0.3875
# Epoch 72/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6347 - categorical_accuracy: 0.4461 - val_loss: 1.8277 - val_categorical_accuracy: 0.3656
# Epoch 73/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6333 - categorical_accuracy: 0.4330 - val_loss: 1.8290 - val_categorical_accuracy: 0.3484
# Epoch 74/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6487 - categorical_accuracy: 0.4339 - val_loss: 1.7773 - val_categorical_accuracy: 0.3891
# Epoch 75/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6476 - categorical_accuracy: 0.4339 - val_loss: 1.8267 - val_categorical_accuracy: 0.3828
# Epoch 76/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6406 - categorical_accuracy: 0.4344 - val_loss: 1.8077 - val_categorical_accuracy: 0.3688
# Epoch 77/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6292 - categorical_accuracy: 0.4422 - val_loss: 1.7976 - val_categorical_accuracy: 0.3859
# Epoch 78/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6295 - categorical_accuracy: 0.4402 - val_loss: 1.7996 - val_categorical_accuracy: 0.3484
# Epoch 79/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6254 - categorical_accuracy: 0.4339 - val_loss: 1.7878 - val_categorical_accuracy: 0.3953
# Epoch 80/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6354 - categorical_accuracy: 0.4358 - val_loss: 1.8253 - val_categorical_accuracy: 0.3766
# Epoch 81/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6217 - categorical_accuracy: 0.4488 - val_loss: 1.7791 - val_categorical_accuracy: 0.3922
# Epoch 82/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.5990 - categorical_accuracy: 0.4495 - val_loss: 1.7927 - val_categorical_accuracy: 0.3891
# Epoch 83/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6122 - categorical_accuracy: 0.4469 - val_loss: 1.7882 - val_categorical_accuracy: 0.3828
# Epoch 84/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6156 - categorical_accuracy: 0.4450 - val_loss: 1.8435 - val_categorical_accuracy: 0.3828
# Epoch 85/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6111 - categorical_accuracy: 0.4520 - val_loss: 1.8006 - val_categorical_accuracy: 0.3734
# Epoch 86/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6088 - categorical_accuracy: 0.4553 - val_loss: 1.7871 - val_categorical_accuracy: 0.3844
# Epoch 87/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6272 - categorical_accuracy: 0.4445 - val_loss: 1.8041 - val_categorical_accuracy: 0.3688
# Epoch 88/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.5979 - categorical_accuracy: 0.4482 - val_loss: 1.7946 - val_categorical_accuracy: 0.4047
# Epoch 89/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6008 - categorical_accuracy: 0.4541 - val_loss: 1.8320 - val_categorical_accuracy: 0.3688
# Epoch 90/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.5923 - categorical_accuracy: 0.4561 - val_loss: 1.8252 - val_categorical_accuracy: 0.3969
# Epoch 91/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6141 - categorical_accuracy: 0.4442 - val_loss: 1.7943 - val_categorical_accuracy: 0.3906
# Epoch 92/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6152 - categorical_accuracy: 0.4476 - val_loss: 1.7882 - val_categorical_accuracy: 0.3953
# Epoch 93/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6166 - categorical_accuracy: 0.4462 - val_loss: 1.8084 - val_categorical_accuracy: 0.3844
# Epoch 94/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6103 - categorical_accuracy: 0.4476 - val_loss: 1.8192 - val_categorical_accuracy: 0.3734
# Epoch 95/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.5924 - categorical_accuracy: 0.4631 - val_loss: 1.8007 - val_categorical_accuracy: 0.3953
# Epoch 96/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.5943 - categorical_accuracy: 0.4539 - val_loss: 1.8119 - val_categorical_accuracy: 0.3922
# Epoch 97/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.6080 - categorical_accuracy: 0.4554 - val_loss: 1.7854 - val_categorical_accuracy: 0.4000
# Epoch 98/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.5856 - categorical_accuracy: 0.4589 - val_loss: 1.8138 - val_categorical_accuracy: 0.4078
# Epoch 99/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.5935 - categorical_accuracy: 0.4534 - val_loss: 1.8552 - val_categorical_accuracy: 0.3828
# Epoch 100/100
# 5757/5757 [==============================] - 8s 1ms/step - loss: 1.5898 - categorical_accuracy: 0.4626 - val_loss: 1.8002 - val_categorical_accuracy: 0.4000
# Train:
# [1.6102663179813221, 0.4517742693424225]
# Val:
# [1.756848497390747, 0.35499998927116394]

# %%
activation='relu'
optimizer = keras.optimizers.Adam(lr=0.0001)
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(16, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation, input_shape=(128, max_dim, 1)))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dropout(0.5))
model.add(Conv2D(16, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dropout(0.5))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2(), activation=activation))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(X_train, y_train, validation_split=0.1, epochs=200, verbose=0, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Train:
# [1.4008204823306563, 0.5465061664581299]
# Val:
# [1.6016042804718018, 0.45249998569488525]

# %%
activation='relu'
optimizer = keras.optimizers.Adam(lr=0.0001)
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(16, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, input_shape=(128, max_dim, 1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(16, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.5))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2()))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(X_train, y_train, validation_split=0.1, epochs=100, verbose=1, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Train on 5757 samples, validate on 640 samples
# Epoch 1/100
# 5757/5757 [==============================] - 16s 3ms/step - loss: 2.8246 - categorical_accuracy: 0.2100 - val_loss: 3.7893 - val_categorical_accuracy: 0.0719
# Epoch 2/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 2.6098 - categorical_accuracy: 0.2640 - val_loss: 5.4313 - val_categorical_accuracy: 0.0719
# Epoch 3/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 2.4271 - categorical_accuracy: 0.3153 - val_loss: 4.8106 - val_categorical_accuracy: 0.0719
# Epoch 4/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 2.2797 - categorical_accuracy: 0.3629 - val_loss: 2.5016 - val_categorical_accuracy: 0.3484
# Epoch 5/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 2.1729 - categorical_accuracy: 0.3834 - val_loss: 2.1007 - val_categorical_accuracy: 0.4016
# Epoch 6/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 2.1043 - categorical_accuracy: 0.4037 - val_loss: 2.3265 - val_categorical_accuracy: 0.4109
# Epoch 7/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 2.0669 - categorical_accuracy: 0.4186 - val_loss: 2.1766 - val_categorical_accuracy: 0.3984
# Epoch 8/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.9643 - categorical_accuracy: 0.4563 - val_loss: 1.9009 - val_categorical_accuracy: 0.4531
# Epoch 9/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.9333 - categorical_accuracy: 0.4574 - val_loss: 2.0267 - val_categorical_accuracy: 0.4406
# Epoch 10/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.8936 - categorical_accuracy: 0.4692 - val_loss: 1.8697 - val_categorical_accuracy: 0.4750
# Epoch 11/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.8386 - categorical_accuracy: 0.4832 - val_loss: 1.9725 - val_categorical_accuracy: 0.4750
# Epoch 12/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.7710 - categorical_accuracy: 0.4911 - val_loss: 2.0805 - val_categorical_accuracy: 0.4281
# Epoch 13/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.7416 - categorical_accuracy: 0.5022 - val_loss: 2.0730 - val_categorical_accuracy: 0.4328
# Epoch 14/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.6957 - categorical_accuracy: 0.5124 - val_loss: 1.9217 - val_categorical_accuracy: 0.4734
# Epoch 15/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.6570 - categorical_accuracy: 0.5310 - val_loss: 2.0743 - val_categorical_accuracy: 0.4125
# Epoch 16/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.5981 - categorical_accuracy: 0.5388 - val_loss: 2.0144 - val_categorical_accuracy: 0.4375
# Epoch 17/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.5718 - categorical_accuracy: 0.5548 - val_loss: 1.9745 - val_categorical_accuracy: 0.4625
# Epoch 18/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.5460 - categorical_accuracy: 0.5628 - val_loss: 1.9792 - val_categorical_accuracy: 0.4422
# Epoch 19/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.4875 - categorical_accuracy: 0.5776 - val_loss: 1.9226 - val_categorical_accuracy: 0.4328
# Epoch 20/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.4629 - categorical_accuracy: 0.5833 - val_loss: 1.9313 - val_categorical_accuracy: 0.4766
# Epoch 21/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.4294 - categorical_accuracy: 0.5873 - val_loss: 1.9222 - val_categorical_accuracy: 0.4437
# Epoch 22/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.3835 - categorical_accuracy: 0.6041 - val_loss: 1.9152 - val_categorical_accuracy: 0.4406
# Epoch 23/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.3431 - categorical_accuracy: 0.6215 - val_loss: 1.9962 - val_categorical_accuracy: 0.4422
# Epoch 24/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.3053 - categorical_accuracy: 0.6279 - val_loss: 2.0278 - val_categorical_accuracy: 0.4391
# Epoch 25/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.2972 - categorical_accuracy: 0.6283 - val_loss: 1.9408 - val_categorical_accuracy: 0.4625
# Epoch 26/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.2574 - categorical_accuracy: 0.6476 - val_loss: 1.9028 - val_categorical_accuracy: 0.4703
# Epoch 27/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.2244 - categorical_accuracy: 0.6589 - val_loss: 1.9046 - val_categorical_accuracy: 0.4781
# Epoch 28/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.2094 - categorical_accuracy: 0.6566 - val_loss: 1.9235 - val_categorical_accuracy: 0.4578
# Epoch 29/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.1522 - categorical_accuracy: 0.6722 - val_loss: 2.0992 - val_categorical_accuracy: 0.4578
# Epoch 30/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.1447 - categorical_accuracy: 0.6781 - val_loss: 2.0322 - val_categorical_accuracy: 0.4547
# Epoch 31/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.1350 - categorical_accuracy: 0.6785 - val_loss: 2.0474 - val_categorical_accuracy: 0.4328
# Epoch 32/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.0793 - categorical_accuracy: 0.6972 - val_loss: 1.9968 - val_categorical_accuracy: 0.4437
# Epoch 33/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.0891 - categorical_accuracy: 0.6939 - val_loss: 1.8589 - val_categorical_accuracy: 0.4859
# Epoch 34/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 1.0355 - categorical_accuracy: 0.7070 - val_loss: 2.0490 - val_categorical_accuracy: 0.4516
# Epoch 35/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.9863 - categorical_accuracy: 0.7191 - val_loss: 2.0146 - val_categorical_accuracy: 0.4812
# Epoch 36/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.9864 - categorical_accuracy: 0.7249 - val_loss: 1.9322 - val_categorical_accuracy: 0.4797
# Epoch 37/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.9677 - categorical_accuracy: 0.7280 - val_loss: 2.0362 - val_categorical_accuracy: 0.4656
# Epoch 38/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.9327 - categorical_accuracy: 0.7386 - val_loss: 2.1269 - val_categorical_accuracy: 0.4688
# Epoch 39/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.9322 - categorical_accuracy: 0.7481 - val_loss: 2.0096 - val_categorical_accuracy: 0.4672
# Epoch 40/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.9303 - categorical_accuracy: 0.7419 - val_loss: 2.1443 - val_categorical_accuracy: 0.4688
# Epoch 41/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.8941 - categorical_accuracy: 0.7502 - val_loss: 2.0537 - val_categorical_accuracy: 0.4656
# Epoch 42/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.8558 - categorical_accuracy: 0.7632 - val_loss: 2.0103 - val_categorical_accuracy: 0.4938
# Epoch 43/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.8883 - categorical_accuracy: 0.7504 - val_loss: 2.0889 - val_categorical_accuracy: 0.4750
# Epoch 44/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.8356 - categorical_accuracy: 0.7700 - val_loss: 2.2266 - val_categorical_accuracy: 0.4688
# Epoch 45/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.8212 - categorical_accuracy: 0.7707 - val_loss: 2.0699 - val_categorical_accuracy: 0.4719
# Epoch 46/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.7944 - categorical_accuracy: 0.7830 - val_loss: 2.0382 - val_categorical_accuracy: 0.4844
# Epoch 47/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.7830 - categorical_accuracy: 0.7867 - val_loss: 2.0026 - val_categorical_accuracy: 0.4797
# Epoch 48/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.7638 - categorical_accuracy: 0.7964 - val_loss: 2.1854 - val_categorical_accuracy: 0.4641
# Epoch 49/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.7416 - categorical_accuracy: 0.7980 - val_loss: 2.1168 - val_categorical_accuracy: 0.4703
# Epoch 50/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.7393 - categorical_accuracy: 0.7992 - val_loss: 2.0576 - val_categorical_accuracy: 0.4859
# Epoch 51/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.7054 - categorical_accuracy: 0.8093 - val_loss: 2.2451 - val_categorical_accuracy: 0.4563
# Epoch 52/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.6810 - categorical_accuracy: 0.8147 - val_loss: 2.0826 - val_categorical_accuracy: 0.4812
# Epoch 53/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.6861 - categorical_accuracy: 0.8107 - val_loss: 2.1895 - val_categorical_accuracy: 0.4594
# Epoch 54/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.6676 - categorical_accuracy: 0.8218 - val_loss: 2.1863 - val_categorical_accuracy: 0.4672
# Epoch 55/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.6667 - categorical_accuracy: 0.8211 - val_loss: 2.2368 - val_categorical_accuracy: 0.4625
# Epoch 56/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.6628 - categorical_accuracy: 0.8185 - val_loss: 2.2178 - val_categorical_accuracy: 0.4703
# Epoch 57/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.6355 - categorical_accuracy: 0.8254 - val_loss: 2.1090 - val_categorical_accuracy: 0.4812
# Epoch 58/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.6384 - categorical_accuracy: 0.8270 - val_loss: 2.2464 - val_categorical_accuracy: 0.4812
# Epoch 59/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.6227 - categorical_accuracy: 0.8348 - val_loss: 2.3112 - val_categorical_accuracy: 0.4844
# Epoch 60/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.6225 - categorical_accuracy: 0.8329 - val_loss: 2.2361 - val_categorical_accuracy: 0.4672
# Epoch 61/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.6068 - categorical_accuracy: 0.8385 - val_loss: 2.3971 - val_categorical_accuracy: 0.4781
# Epoch 62/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.5830 - categorical_accuracy: 0.8487 - val_loss: 2.2521 - val_categorical_accuracy: 0.4641
# Epoch 63/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.5771 - categorical_accuracy: 0.8381 - val_loss: 2.2136 - val_categorical_accuracy: 0.4672
# Epoch 64/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.5997 - categorical_accuracy: 0.8392 - val_loss: 2.3427 - val_categorical_accuracy: 0.4719
# Epoch 65/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.5496 - categorical_accuracy: 0.8607 - val_loss: 2.2533 - val_categorical_accuracy: 0.4859
# Epoch 66/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.5472 - categorical_accuracy: 0.8560 - val_loss: 2.7256 - val_categorical_accuracy: 0.4156
# Epoch 67/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.5403 - categorical_accuracy: 0.8612 - val_loss: 2.2886 - val_categorical_accuracy: 0.4844
# Epoch 68/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.5090 - categorical_accuracy: 0.8701 - val_loss: 2.3786 - val_categorical_accuracy: 0.4609
# Epoch 69/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.5255 - categorical_accuracy: 0.8621 - val_loss: 2.4569 - val_categorical_accuracy: 0.4453
# Epoch 70/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.5246 - categorical_accuracy: 0.8593 - val_loss: 2.2770 - val_categorical_accuracy: 0.4781
# Epoch 71/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.5255 - categorical_accuracy: 0.8614 - val_loss: 2.4524 - val_categorical_accuracy: 0.4750
# Epoch 72/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.5205 - categorical_accuracy: 0.8572 - val_loss: 2.5630 - val_categorical_accuracy: 0.4453
# Epoch 73/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4971 - categorical_accuracy: 0.8727 - val_loss: 2.5399 - val_categorical_accuracy: 0.4391
# Epoch 74/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4939 - categorical_accuracy: 0.8758 - val_loss: 2.3522 - val_categorical_accuracy: 0.4703
# Epoch 75/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4650 - categorical_accuracy: 0.8767 - val_loss: 2.5218 - val_categorical_accuracy: 0.4563
# Epoch 76/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4797 - categorical_accuracy: 0.8777 - val_loss: 2.4846 - val_categorical_accuracy: 0.4469
# Epoch 77/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4569 - categorical_accuracy: 0.8836 - val_loss: 2.4898 - val_categorical_accuracy: 0.4656
# Epoch 78/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4500 - categorical_accuracy: 0.8866 - val_loss: 2.6634 - val_categorical_accuracy: 0.4594
# Epoch 79/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4599 - categorical_accuracy: 0.8821 - val_loss: 2.3658 - val_categorical_accuracy: 0.4812
# Epoch 80/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4453 - categorical_accuracy: 0.8845 - val_loss: 2.4839 - val_categorical_accuracy: 0.4844
# Epoch 81/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4485 - categorical_accuracy: 0.8831 - val_loss: 2.4000 - val_categorical_accuracy: 0.4719
# Epoch 82/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4171 - categorical_accuracy: 0.8947 - val_loss: 2.4984 - val_categorical_accuracy: 0.4641
# Epoch 83/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4014 - categorical_accuracy: 0.8972 - val_loss: 2.3773 - val_categorical_accuracy: 0.4812
# Epoch 84/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4271 - categorical_accuracy: 0.8918 - val_loss: 2.3978 - val_categorical_accuracy: 0.4563
# Epoch 85/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4044 - categorical_accuracy: 0.9003 - val_loss: 2.5713 - val_categorical_accuracy: 0.4500
# Epoch 86/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4369 - categorical_accuracy: 0.8857 - val_loss: 2.5838 - val_categorical_accuracy: 0.4812
# Epoch 87/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4001 - categorical_accuracy: 0.9005 - val_loss: 2.5631 - val_categorical_accuracy: 0.4406
# Epoch 88/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.4127 - categorical_accuracy: 0.8900 - val_loss: 2.4699 - val_categorical_accuracy: 0.4672
# Epoch 89/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.3986 - categorical_accuracy: 0.8996 - val_loss: 2.5465 - val_categorical_accuracy: 0.4609
# Epoch 90/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.3881 - categorical_accuracy: 0.8972 - val_loss: 2.6629 - val_categorical_accuracy: 0.4516
# Epoch 91/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.3674 - categorical_accuracy: 0.9076 - val_loss: 2.4612 - val_categorical_accuracy: 0.4891
# Epoch 92/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.3687 - categorical_accuracy: 0.9090 - val_loss: 2.6986 - val_categorical_accuracy: 0.4516
# Epoch 93/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.3792 - categorical_accuracy: 0.9046 - val_loss: 2.5019 - val_categorical_accuracy: 0.4531
# Epoch 94/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.3532 - categorical_accuracy: 0.9133 - val_loss: 2.5291 - val_categorical_accuracy: 0.4688
# Epoch 95/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.3666 - categorical_accuracy: 0.9118 - val_loss: 2.6734 - val_categorical_accuracy: 0.4516
# Epoch 96/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.3778 - categorical_accuracy: 0.9060 - val_loss: 2.5850 - val_categorical_accuracy: 0.4828
# Epoch 97/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.3513 - categorical_accuracy: 0.9159 - val_loss: 2.7146 - val_categorical_accuracy: 0.4313
# Epoch 98/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.3628 - categorical_accuracy: 0.9104 - val_loss: 2.6169 - val_categorical_accuracy: 0.4578
# Epoch 99/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.3578 - categorical_accuracy: 0.9083 - val_loss: 2.7029 - val_categorical_accuracy: 0.4594
# Epoch 100/100
# 5757/5757 [==============================] - 15s 3ms/step - loss: 0.3698 - categorical_accuracy: 0.9048 - val_loss: 2.9109 - val_categorical_accuracy: 0.4359
# Train:
# [0.7410439397648795, 0.8271064758300781]
# Val:
# [2.1436762237548828, 0.4437499940395355]

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rotation_range=20, width_shift_range=0.2, height_shift_range=0.2, horizontal_flip=True, fill_mode='nearest', validation_split=0.1)
train_batchsize = 32
val_batchsize = 16

train_generator = train_datagen.flow(X_train, y_train, batch_size=train_batchsize)
val_generator = train_datagen.flow(X_train, y_train, batch_size=val_batchsize, subset='validation')

# %%
activation='relu'
optimizer = keras.optimizers.Adam(lr=0.0001)
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(16, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation, input_shape=(128, max_dim, 1)))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dropout(0.3))
model.add(Conv2D(16, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation))
model.add(MaxPool2D(pool_size=(2,4)))
model.add(Dropout(0.3))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2(), activation=activation))
model.add(Flatten())
model.add(Dropout(0.3))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec-generator-dropout.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(train_generator, steps_per_epoch=len(X_train)/ train_batchsize, epochs=200, validation_data=val_generator, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec-generator-dropout.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Epoch 1/200
# 200/199 [==============================] - 36s 182ms/step - loss: 2.3632 - categorical_accuracy: 0.1287 - val_loss: 2.3089 - val_categorical_accuracy: 0.1643
# Epoch 2/200
# 200/199 [==============================] - 34s 171ms/step - loss: 2.2920 - categorical_accuracy: 0.1405 - val_loss: 2.2664 - val_categorical_accuracy: 0.0626
# Epoch 3/200
# 200/199 [==============================] - 34s 168ms/step - loss: 2.2353 - categorical_accuracy: 0.1673 - val_loss: 2.1894 - val_categorical_accuracy: 0.1268
# Epoch 4/200
# 200/199 [==============================] - 34s 170ms/step - loss: 2.1823 - categorical_accuracy: 0.2057 - val_loss: 2.1616 - val_categorical_accuracy: 0.2207
# Epoch 5/200
# 200/199 [==============================] - 34s 168ms/step - loss: 2.1058 - categorical_accuracy: 0.2581 - val_loss: 2.0346 - val_categorical_accuracy: 0.3412
# Epoch 6/200
# 200/199 [==============================] - 34s 168ms/step - loss: 2.0336 - categorical_accuracy: 0.2784 - val_loss: 2.1956 - val_categorical_accuracy: 0.2848
# Epoch 7/200
# 200/199 [==============================] - 34s 168ms/step - loss: 1.9931 - categorical_accuracy: 0.2959 - val_loss: 1.8643 - val_categorical_accuracy: 0.2958
# Epoch 8/200
# 200/199 [==============================] - 34s 170ms/step - loss: 1.9514 - categorical_accuracy: 0.3209 - val_loss: 1.5954 - val_categorical_accuracy: 0.3161
# Epoch 9/200
# 200/199 [==============================] - 34s 172ms/step - loss: 1.9294 - categorical_accuracy: 0.3167 - val_loss: 1.5875 - val_categorical_accuracy: 0.3991
# Epoch 10/200
# 200/199 [==============================] - 34s 171ms/step - loss: 1.9085 - categorical_accuracy: 0.3264 - val_loss: 1.8217 - val_categorical_accuracy: 0.3396
# Epoch 11/200
# 200/199 [==============================] - 34s 172ms/step - loss: 1.8975 - categorical_accuracy: 0.3303 - val_loss: 1.7205 - val_categorical_accuracy: 0.3740
# Epoch 12/200
# 200/199 [==============================] - 34s 170ms/step - loss: 1.8791 - categorical_accuracy: 0.3413 - val_loss: 1.9606 - val_categorical_accuracy: 0.4069
# Epoch 13/200
# 200/199 [==============================] - 35s 173ms/step - loss: 1.8633 - categorical_accuracy: 0.3422 - val_loss: 1.6588 - val_categorical_accuracy: 0.3599
# Epoch 14/200
# 200/199 [==============================] - 35s 174ms/step - loss: 1.8780 - categorical_accuracy: 0.3300 - val_loss: 1.8638 - val_categorical_accuracy: 0.3255
# Epoch 15/200
# 200/199 [==============================] - 35s 174ms/step - loss: 1.8634 - categorical_accuracy: 0.3428 - val_loss: 1.8347 - val_categorical_accuracy: 0.3662
# Epoch 16/200
# 200/199 [==============================] - 35s 175ms/step - loss: 1.8566 - categorical_accuracy: 0.3441 - val_loss: 1.8683 - val_categorical_accuracy: 0.4116
# Epoch 17/200
# 200/199 [==============================] - 34s 171ms/step - loss: 1.8590 - categorical_accuracy: 0.3470 - val_loss: 1.5549 - val_categorical_accuracy: 0.3740
# Epoch 18/200
# 200/199 [==============================] - 34s 170ms/step - loss: 1.8465 - categorical_accuracy: 0.3442 - val_loss: 2.0246 - val_categorical_accuracy: 0.3740
# Epoch 19/200
# 200/199 [==============================] - 34s 169ms/step - loss: 1.8433 - categorical_accuracy: 0.3553 - val_loss: 1.9177 - val_categorical_accuracy: 0.3881
# Epoch 20/200
# 200/199 [==============================] - 34s 169ms/step - loss: 1.8477 - categorical_accuracy: 0.3456 - val_loss: 1.8069 - val_categorical_accuracy: 0.4225
# Epoch 21/200
# 200/199 [==============================] - 34s 168ms/step - loss: 1.8431 - categorical_accuracy: 0.3531 - val_loss: 1.5801 - val_categorical_accuracy: 0.3333
# Epoch 22/200
# 200/199 [==============================] - 34s 169ms/step - loss: 1.8334 - categorical_accuracy: 0.3544 - val_loss: 1.5407 - val_categorical_accuracy: 0.3740
# Epoch 23/200
# 200/199 [==============================] - 34s 169ms/step - loss: 1.8279 - categorical_accuracy: 0.3589 - val_loss: 1.6106 - val_categorical_accuracy: 0.3834
# Epoch 24/200
# 200/199 [==============================] - 34s 168ms/step - loss: 1.8289 - categorical_accuracy: 0.3508 - val_loss: 1.4299 - val_categorical_accuracy: 0.4413
# Epoch 25/200
# 200/199 [==============================] - 34s 169ms/step - loss: 1.8211 - categorical_accuracy: 0.3569 - val_loss: 1.8466 - val_categorical_accuracy: 0.4022
# Epoch 26/200
# 200/199 [==============================] - 34s 168ms/step - loss: 1.8241 - categorical_accuracy: 0.3552 - val_loss: 1.5190 - val_categorical_accuracy: 0.3959
# Epoch 27/200
# 200/199 [==============================] - 34s 168ms/step - loss: 1.8159 - categorical_accuracy: 0.3627 - val_loss: 1.6185 - val_categorical_accuracy: 0.4460
# Epoch 28/200
# 200/199 [==============================] - 34s 168ms/step - loss: 1.8171 - categorical_accuracy: 0.3614 - val_loss: 1.8216 - val_categorical_accuracy: 0.4038
# Epoch 29/200
# 200/199 [==============================] - 34s 168ms/step - loss: 1.8163 - categorical_accuracy: 0.3600 - val_loss: 1.8710 - val_categorical_accuracy: 0.4147
# Epoch 30/200
# 200/199 [==============================] - 34s 169ms/step - loss: 1.8147 - categorical_accuracy: 0.3624 - val_loss: 1.6381 - val_categorical_accuracy: 0.3803
# Epoch 31/200
# 200/199 [==============================] - 34s 169ms/step - loss: 1.8104 - categorical_accuracy: 0.3706 - val_loss: 1.6951 - val_categorical_accuracy: 0.3928
# Epoch 32/200
# 200/199 [==============================] - 34s 169ms/step - loss: 1.8107 - categorical_accuracy: 0.3708 - val_loss: 1.6956 - val_categorical_accuracy: 0.4257
# Epoch 33/200
# 200/199 [==============================] - 33s 167ms/step - loss: 1.8063 - categorical_accuracy: 0.3645 - val_loss: 1.6400 - val_categorical_accuracy: 0.4069
# Epoch 34/200
# 200/199 [==============================] - 33s 167ms/step - loss: 1.8013 - categorical_accuracy: 0.3642 - val_loss: 1.7760 - val_categorical_accuracy: 0.4085
# Epoch 35/200
# 200/199 [==============================] - 33s 166ms/step - loss: 1.7976 - categorical_accuracy: 0.3617 - val_loss: 2.0443 - val_categorical_accuracy: 0.4210
# Epoch 36/200
# 200/199 [==============================] - 33s 167ms/step - loss: 1.7982 - categorical_accuracy: 0.3694 - val_loss: 1.4578 - val_categorical_accuracy: 0.4069
# Epoch 37/200
# 200/199 [==============================] - 34s 168ms/step - loss: 1.7975 - categorical_accuracy: 0.3660 - val_loss: 1.5715 - val_categorical_accuracy: 0.3662
# Epoch 38/200
# 200/199 [==============================] - 33s 166ms/step - loss: 1.7979 - categorical_accuracy: 0.3736 - val_loss: 1.9231 - val_categorical_accuracy: 0.4006
# Epoch 39/200
# 200/199 [==============================] - 33s 167ms/step - loss: 1.7953 - categorical_accuracy: 0.3652 - val_loss: 1.5205 - val_categorical_accuracy: 0.3584
# Epoch 40/200
# 200/199 [==============================] - 33s 165ms/step - loss: 1.7957 - categorical_accuracy: 0.3664 - val_loss: 1.6058 - val_categorical_accuracy: 0.3693
# Epoch 41/200
# 200/199 [==============================] - 33s 167ms/step - loss: 1.7914 - categorical_accuracy: 0.3727 - val_loss: 1.6230 - val_categorical_accuracy: 0.3678
# Epoch 42/200
# 200/199 [==============================] - 33s 165ms/step - loss: 1.7866 - categorical_accuracy: 0.3755 - val_loss: 2.1972 - val_categorical_accuracy: 0.3693
# Epoch 43/200
# 200/199 [==============================] - 33s 164ms/step - loss: 1.7870 - categorical_accuracy: 0.3724 - val_loss: 1.4062 - val_categorical_accuracy: 0.4444
# Epoch 44/200
# 200/199 [==============================] - 33s 165ms/step - loss: 1.7886 - categorical_accuracy: 0.3685 - val_loss: 1.4649 - val_categorical_accuracy: 0.4225
# Epoch 45/200
# 200/199 [==============================] - 33s 164ms/step - loss: 1.7811 - categorical_accuracy: 0.3714 - val_loss: 1.4757 - val_categorical_accuracy: 0.4100
# Epoch 46/200
# 200/199 [==============================] - 33s 164ms/step - loss: 1.7785 - categorical_accuracy: 0.3735 - val_loss: 1.6113 - val_categorical_accuracy: 0.3271
# Epoch 47/200
# 200/199 [==============================] - 33s 164ms/step - loss: 1.7798 - categorical_accuracy: 0.3719 - val_loss: 1.5941 - val_categorical_accuracy: 0.3756
# Epoch 48/200
# 200/199 [==============================] - 33s 164ms/step - loss: 1.7812 - categorical_accuracy: 0.3774 - val_loss: 1.6280 - val_categorical_accuracy: 0.4304
# Epoch 49/200
# 200/199 [==============================] - 33s 165ms/step - loss: 1.7739 - categorical_accuracy: 0.3747 - val_loss: 1.9880 - val_categorical_accuracy: 0.4194
# Epoch 50/200
# 200/199 [==============================] - 33s 165ms/step - loss: 1.7781 - categorical_accuracy: 0.3766 - val_loss: 1.5910 - val_categorical_accuracy: 0.4085
# Epoch 51/200
# 200/199 [==============================] - 33s 164ms/step - loss: 1.7682 - categorical_accuracy: 0.3780 - val_loss: 1.7233 - val_categorical_accuracy: 0.4194
# Epoch 52/200
# 200/199 [==============================] - 33s 165ms/step - loss: 1.7709 - categorical_accuracy: 0.3755 - val_loss: 1.6291 - val_categorical_accuracy: 0.4053
# Epoch 53/200
# 200/199 [==============================] - 33s 164ms/step - loss: 1.7683 - categorical_accuracy: 0.3796 - val_loss: 1.7869 - val_categorical_accuracy: 0.3991
# Epoch 54/200
# 200/199 [==============================] - 33s 165ms/step - loss: 1.7669 - categorical_accuracy: 0.3786 - val_loss: 1.5539 - val_categorical_accuracy: 0.4397
# Epoch 55/200
# 200/199 [==============================] - 33s 164ms/step - loss: 1.7675 - categorical_accuracy: 0.3717 - val_loss: 1.7740 - val_categorical_accuracy: 0.3944
# Epoch 56/200
# 200/199 [==============================] - 33s 165ms/step - loss: 1.7679 - categorical_accuracy: 0.3786 - val_loss: 1.6595 - val_categorical_accuracy: 0.4413
# Epoch 57/200
#  36/199 [====>.........................] - ETA: 19s - loss: 1.7691 - categorical_accuracy: 0.3689

# %%
activation='relu'
optimizer = keras.optimizers.Adam()
metrics=['categorical_accuracy']

model = keras.Sequential()
model.add(Conv2D(16, kernel_size=3, kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation, input_shape=(128, max_dim, 1)))
model.add(MaxPool2D(pool_size=(2,4)))
#model.add(Dropout(0.5))
model.add(Conv2D(16, kernel_size=(3,5), kernel_regularizer=keras.regularizers.l2(), strides=1, activation=activation))
model.add(MaxPool2D(pool_size=(2,4)))
#model.add(Dropout(0.5))
model.add(Dense(16, kernel_regularizer=keras.regularizers.l2(), activation=activation))
model.add(Flatten())
#model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer=optimizer, loss=keras.losses.CategoricalCrossentropy(), metrics=metrics)
mcp_save = ModelCheckpoint('best_model_cnn_mel-spec-generator.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(train_generator, steps_per_epoch=len(X_train)/ train_batchsize, epochs=100, validation_data=val_generator, callbacks=[mcp_save])
plt.plot(history.history['' + metrics[0]])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

best_model = load_model('best_model_cnn_mel-spec-generator.hdf5')
print("Train:")
print(best_model.evaluate(X_train, y_train, verbose=2))
print("Val:")
print(best_model.evaluate(X_val, y_val, verbose=2))
# Out:
# Epoch 1/100
# 200/199 [==============================] - 64s 319ms/step - loss: 2.2516 - categorical_accuracy: 0.1296 - val_loss: 2.1997 - val_categorical_accuracy: 0.1509
# Epoch 2/100
# 200/199 [==============================] - 62s 308ms/step - loss: 2.0898 - categorical_accuracy: 0.1896 - val_loss: 2.1265 - val_categorical_accuracy: 0.2226
# Epoch 3/100
# 200/199 [==============================] - 62s 312ms/step - loss: 2.0027 - categorical_accuracy: 0.2421 - val_loss: 2.0722 - val_categorical_accuracy: 0.2343
# Epoch 4/100
# 200/199 [==============================] - 61s 306ms/step - loss: 1.9279 - categorical_accuracy: 0.2640 - val_loss: 1.8874 - val_categorical_accuracy: 0.2995
# Epoch 5/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.8875 - categorical_accuracy: 0.2854 - val_loss: 2.0242 - val_categorical_accuracy: 0.2869
# Epoch 6/100
# 200/199 [==============================] - 61s 306ms/step - loss: 1.8614 - categorical_accuracy: 0.3012 - val_loss: 1.6921 - val_categorical_accuracy: 0.3184
# Epoch 7/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.8485 - categorical_accuracy: 0.3019 - val_loss: 2.0531 - val_categorical_accuracy: 0.3111
# Epoch 8/100
# 200/199 [==============================] - 61s 305ms/step - loss: 1.8371 - categorical_accuracy: 0.3198 - val_loss: 2.0410 - val_categorical_accuracy: 0.2826
# Epoch 9/100
# 200/199 [==============================] - 61s 306ms/step - loss: 1.8304 - categorical_accuracy: 0.3186 - val_loss: 1.9739 - val_categorical_accuracy: 0.3262
# Epoch 10/100
# 200/199 [==============================] - 61s 305ms/step - loss: 1.8179 - categorical_accuracy: 0.3205 - val_loss: 1.9178 - val_categorical_accuracy: 0.3323
# Epoch 11/100
# 200/199 [==============================] - 61s 306ms/step - loss: 1.8082 - categorical_accuracy: 0.3256 - val_loss: 1.7976 - val_categorical_accuracy: 0.3295
# Epoch 12/100
# 200/199 [==============================] - 61s 306ms/step - loss: 1.8099 - categorical_accuracy: 0.3311 - val_loss: 2.0392 - val_categorical_accuracy: 0.3312
# Epoch 13/100
# 200/199 [==============================] - 62s 310ms/step - loss: 1.7965 - categorical_accuracy: 0.3325 - val_loss: 2.1342 - val_categorical_accuracy: 0.3306
# Epoch 14/100
# 200/199 [==============================] - 62s 310ms/step - loss: 1.8200 - categorical_accuracy: 0.3295 - val_loss: 1.7219 - val_categorical_accuracy: 0.3264
# Epoch 15/100
# 200/199 [==============================] - 62s 312ms/step - loss: 1.8038 - categorical_accuracy: 0.3347 - val_loss: 1.6809 - val_categorical_accuracy: 0.3364
# Epoch 16/100
# 200/199 [==============================] - 64s 319ms/step - loss: 1.8064 - categorical_accuracy: 0.3287 - val_loss: 1.7836 - val_categorical_accuracy: 0.3297
# Epoch 17/100
# 200/199 [==============================] - 62s 312ms/step - loss: 1.8066 - categorical_accuracy: 0.3305 - val_loss: 1.5364 - val_categorical_accuracy: 0.3503
# Epoch 18/100
# 200/199 [==============================] - 62s 311ms/step - loss: 1.7960 - categorical_accuracy: 0.3309 - val_loss: 1.6915 - val_categorical_accuracy: 0.3423
# Epoch 19/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7976 - categorical_accuracy: 0.3411 - val_loss: 1.5741 - val_categorical_accuracy: 0.3370
# Epoch 20/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7886 - categorical_accuracy: 0.3327 - val_loss: 1.5549 - val_categorical_accuracy: 0.3242
# Epoch 21/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7866 - categorical_accuracy: 0.3438 - val_loss: 1.9461 - val_categorical_accuracy: 0.3434
# Epoch 22/100
# 200/199 [==============================] - 62s 310ms/step - loss: 1.7893 - categorical_accuracy: 0.3327 - val_loss: 1.7467 - val_categorical_accuracy: 0.3570
# Epoch 23/100
# 200/199 [==============================] - 61s 306ms/step - loss: 1.7850 - categorical_accuracy: 0.3430 - val_loss: 1.9922 - val_categorical_accuracy: 0.3114
# Epoch 24/100
# 200/199 [==============================] - 61s 307ms/step - loss: 1.7921 - categorical_accuracy: 0.3489 - val_loss: 1.9474 - val_categorical_accuracy: 0.3338
# Epoch 25/100
# 200/199 [==============================] - 62s 309ms/step - loss: 1.7925 - categorical_accuracy: 0.3353 - val_loss: 1.8143 - val_categorical_accuracy: 0.3486
# Epoch 26/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7810 - categorical_accuracy: 0.3409 - val_loss: 1.7159 - val_categorical_accuracy: 0.3439
# Epoch 27/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7754 - categorical_accuracy: 0.3444 - val_loss: 1.7103 - val_categorical_accuracy: 0.3517
# Epoch 28/100
# 200/199 [==============================] - 61s 307ms/step - loss: 1.7766 - categorical_accuracy: 0.3459 - val_loss: 2.1325 - val_categorical_accuracy: 0.3367
# Epoch 29/100
# 200/199 [==============================] - 61s 307ms/step - loss: 1.7895 - categorical_accuracy: 0.3402 - val_loss: 1.5573 - val_categorical_accuracy: 0.3528
# Epoch 30/100
# 200/199 [==============================] - 62s 309ms/step - loss: 1.7709 - categorical_accuracy: 0.3475 - val_loss: 1.7127 - val_categorical_accuracy: 0.3477
# Epoch 31/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7667 - categorical_accuracy: 0.3499 - val_loss: 2.0060 - val_categorical_accuracy: 0.3522
# Epoch 32/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7630 - categorical_accuracy: 0.3539 - val_loss: 1.7725 - val_categorical_accuracy: 0.3436
# Epoch 33/100
# 200/199 [==============================] - 62s 309ms/step - loss: 1.7685 - categorical_accuracy: 0.3542 - val_loss: 2.2955 - val_categorical_accuracy: 0.3262
# Epoch 34/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7723 - categorical_accuracy: 0.3556 - val_loss: 2.0212 - val_categorical_accuracy: 0.3619
# Epoch 35/100
# 200/199 [==============================] - 62s 309ms/step - loss: 1.7562 - categorical_accuracy: 0.3570 - val_loss: 1.7817 - val_categorical_accuracy: 0.3527
# Epoch 36/100
# 200/199 [==============================] - 61s 307ms/step - loss: 1.7699 - categorical_accuracy: 0.3484 - val_loss: 1.7498 - val_categorical_accuracy: 0.3606
# Epoch 37/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7610 - categorical_accuracy: 0.3572 - val_loss: 1.8244 - val_categorical_accuracy: 0.3577
# Epoch 38/100
# 200/199 [==============================] - 62s 309ms/step - loss: 1.7627 - categorical_accuracy: 0.3539 - val_loss: 1.6154 - val_categorical_accuracy: 0.3584
# Epoch 39/100
# 200/199 [==============================] - 61s 307ms/step - loss: 1.7470 - categorical_accuracy: 0.3558 - val_loss: 1.3613 - val_categorical_accuracy: 0.3519
# Epoch 40/100
# 200/199 [==============================] - 61s 307ms/step - loss: 1.7507 - categorical_accuracy: 0.3564 - val_loss: 1.6647 - val_categorical_accuracy: 0.3678
# Epoch 41/100
# 200/199 [==============================] - 61s 305ms/step - loss: 1.7467 - categorical_accuracy: 0.3545 - val_loss: 1.7477 - val_categorical_accuracy: 0.3503
# Epoch 42/100
# 200/199 [==============================] - 61s 306ms/step - loss: 1.7494 - categorical_accuracy: 0.3602 - val_loss: 1.8072 - val_categorical_accuracy: 0.3641
# Epoch 43/100
# 200/199 [==============================] - 61s 305ms/step - loss: 1.7540 - categorical_accuracy: 0.3567 - val_loss: 1.9997 - val_categorical_accuracy: 0.3405
# Epoch 44/100
# 200/199 [==============================] - 61s 305ms/step - loss: 1.7535 - categorical_accuracy: 0.3619 - val_loss: 1.5287 - val_categorical_accuracy: 0.3544
# Epoch 45/100
# 200/199 [==============================] - 61s 305ms/step - loss: 1.7473 - categorical_accuracy: 0.3586 - val_loss: 2.2048 - val_categorical_accuracy: 0.3588
# Epoch 46/100
# 200/199 [==============================] - 61s 307ms/step - loss: 1.7535 - categorical_accuracy: 0.3533 - val_loss: 1.6697 - val_categorical_accuracy: 0.3575
# Epoch 47/100
# 200/199 [==============================] - 61s 306ms/step - loss: 1.7432 - categorical_accuracy: 0.3572 - val_loss: 1.9216 - val_categorical_accuracy: 0.3714
# Epoch 48/100
# 200/199 [==============================] - 61s 307ms/step - loss: 1.7527 - categorical_accuracy: 0.3589 - val_loss: 1.5042 - val_categorical_accuracy: 0.3015
# Epoch 49/100
# 200/199 [==============================] - 60s 302ms/step - loss: 1.7473 - categorical_accuracy: 0.3588 - val_loss: 1.7144 - val_categorical_accuracy: 0.3650
# Epoch 50/100
# 200/199 [==============================] - 61s 306ms/step - loss: 1.7531 - categorical_accuracy: 0.3550 - val_loss: 1.6227 - val_categorical_accuracy: 0.3614
# Epoch 51/100
# 200/199 [==============================] - 60s 302ms/step - loss: 1.7422 - categorical_accuracy: 0.3603 - val_loss: 1.5867 - val_categorical_accuracy: 0.3666
# Epoch 52/100
# 200/199 [==============================] - 60s 302ms/step - loss: 1.7532 - categorical_accuracy: 0.3528 - val_loss: 1.8545 - val_categorical_accuracy: 0.3650
# Epoch 53/100
# 200/199 [==============================] - 60s 302ms/step - loss: 1.7474 - categorical_accuracy: 0.3667 - val_loss: 1.9343 - val_categorical_accuracy: 0.3731
# Epoch 54/100
# 200/199 [==============================] - 60s 302ms/step - loss: 1.7505 - categorical_accuracy: 0.3610 - val_loss: 1.6622 - val_categorical_accuracy: 0.3658
# Epoch 55/100
# 200/199 [==============================] - 60s 302ms/step - loss: 1.7369 - categorical_accuracy: 0.3586 - val_loss: 1.7994 - val_categorical_accuracy: 0.3728
# Epoch 56/100
# 200/199 [==============================] - 61s 303ms/step - loss: 1.7219 - categorical_accuracy: 0.3681 - val_loss: 1.8205 - val_categorical_accuracy: 0.3630
# Epoch 57/100
# 200/199 [==============================] - 61s 303ms/step - loss: 1.7410 - categorical_accuracy: 0.3633 - val_loss: 1.5797 - val_categorical_accuracy: 0.3714
# Epoch 58/100
# 200/199 [==============================] - 61s 303ms/step - loss: 1.7459 - categorical_accuracy: 0.3633 - val_loss: 1.7149 - val_categorical_accuracy: 0.3530
# Epoch 59/100
# 200/199 [==============================] - 61s 303ms/step - loss: 1.7391 - categorical_accuracy: 0.3713 - val_loss: 1.5120 - val_categorical_accuracy: 0.3652
# Epoch 60/100
# 200/199 [==============================] - 61s 303ms/step - loss: 1.7449 - categorical_accuracy: 0.3549 - val_loss: 1.6002 - val_categorical_accuracy: 0.3647
# Epoch 61/100
# 200/199 [==============================] - 60s 302ms/step - loss: 1.7292 - categorical_accuracy: 0.3691 - val_loss: 1.7026 - val_categorical_accuracy: 0.3628
# Epoch 62/100
# 200/199 [==============================] - 61s 303ms/step - loss: 1.7328 - categorical_accuracy: 0.3691 - val_loss: 1.5170 - val_categorical_accuracy: 0.3614
# Epoch 63/100
# 200/199 [==============================] - 61s 303ms/step - loss: 1.7547 - categorical_accuracy: 0.3616 - val_loss: 1.7493 - val_categorical_accuracy: 0.3663
# Epoch 64/100
# 200/199 [==============================] - 60s 302ms/step - loss: 1.7388 - categorical_accuracy: 0.3625 - val_loss: 1.9379 - val_categorical_accuracy: 0.3577
# Epoch 65/100
# 200/199 [==============================] - 60s 302ms/step - loss: 1.7471 - categorical_accuracy: 0.3594 - val_loss: 1.8308 - val_categorical_accuracy: 0.3788
# Epoch 66/100
# 200/199 [==============================] - 60s 301ms/step - loss: 1.7435 - categorical_accuracy: 0.3599 - val_loss: 1.8655 - val_categorical_accuracy: 0.3675
# Epoch 67/100
# 200/199 [==============================] - 60s 302ms/step - loss: 1.7368 - categorical_accuracy: 0.3655 - val_loss: 1.6898 - val_categorical_accuracy: 0.3742
# Epoch 68/100
# 200/199 [==============================] - 61s 303ms/step - loss: 1.7391 - categorical_accuracy: 0.3624 - val_loss: 1.8611 - val_categorical_accuracy: 0.3653
# Epoch 69/100
# 200/199 [==============================] - 60s 301ms/step - loss: 1.7309 - categorical_accuracy: 0.3697 - val_loss: 1.6188 - val_categorical_accuracy: 0.3733
# Epoch 70/100
# 200/199 [==============================] - 62s 311ms/step - loss: 1.7394 - categorical_accuracy: 0.3616 - val_loss: 1.6003 - val_categorical_accuracy: 0.3685
# Epoch 71/100
# 200/199 [==============================] - 63s 313ms/step - loss: 1.7390 - categorical_accuracy: 0.3624 - val_loss: 1.4662 - val_categorical_accuracy: 0.3509
# Epoch 72/100
# 200/199 [==============================] - 62s 309ms/step - loss: 1.7405 - categorical_accuracy: 0.3577 - val_loss: 1.5837 - val_categorical_accuracy: 0.3603
# Epoch 73/100
# 200/199 [==============================] - 61s 305ms/step - loss: 1.7277 - categorical_accuracy: 0.3694 - val_loss: 2.0321 - val_categorical_accuracy: 0.3694
# Epoch 74/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7341 - categorical_accuracy: 0.3628 - val_loss: 2.2331 - val_categorical_accuracy: 0.3688
# Epoch 75/100
# 200/199 [==============================] - 62s 310ms/step - loss: 1.7356 - categorical_accuracy: 0.3630 - val_loss: 1.8731 - val_categorical_accuracy: 0.3692
# Epoch 76/100
# 200/199 [==============================] - 62s 310ms/step - loss: 1.7264 - categorical_accuracy: 0.3636 - val_loss: 2.1315 - val_categorical_accuracy: 0.3383
# Epoch 77/100
# 200/199 [==============================] - 62s 311ms/step - loss: 1.7284 - categorical_accuracy: 0.3711 - val_loss: 1.6353 - val_categorical_accuracy: 0.3752
# Epoch 78/100
# 200/199 [==============================] - 62s 310ms/step - loss: 1.7271 - categorical_accuracy: 0.3716 - val_loss: 1.5808 - val_categorical_accuracy: 0.3752
# Epoch 79/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7339 - categorical_accuracy: 0.3616 - val_loss: 1.5696 - val_categorical_accuracy: 0.3566
# Epoch 80/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7432 - categorical_accuracy: 0.3666 - val_loss: 2.2683 - val_categorical_accuracy: 0.3481
# Epoch 81/100
# 200/199 [==============================] - 61s 307ms/step - loss: 1.7321 - categorical_accuracy: 0.3664 - val_loss: 1.4961 - val_categorical_accuracy: 0.3756
# Epoch 82/100
# 200/199 [==============================] - 61s 305ms/step - loss: 1.7226 - categorical_accuracy: 0.3731 - val_loss: 1.6754 - val_categorical_accuracy: 0.3800
# Epoch 83/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7217 - categorical_accuracy: 0.3775 - val_loss: 2.1469 - val_categorical_accuracy: 0.3660
# Epoch 84/100
# 200/199 [==============================] - 61s 304ms/step - loss: 1.7307 - categorical_accuracy: 0.3663 - val_loss: 1.5826 - val_categorical_accuracy: 0.3758
# Epoch 85/100
# 200/199 [==============================] - 61s 304ms/step - loss: 1.7309 - categorical_accuracy: 0.3627 - val_loss: 1.4072 - val_categorical_accuracy: 0.3733
# Epoch 86/100
# 200/199 [==============================] - 61s 304ms/step - loss: 1.7252 - categorical_accuracy: 0.3658 - val_loss: 1.7738 - val_categorical_accuracy: 0.3625
# Epoch 87/100
# 200/199 [==============================] - 61s 306ms/step - loss: 1.7291 - categorical_accuracy: 0.3666 - val_loss: 2.0315 - val_categorical_accuracy: 0.3528
# Epoch 88/100
# 200/199 [==============================] - 62s 309ms/step - loss: 1.7366 - categorical_accuracy: 0.3686 - val_loss: 1.9963 - val_categorical_accuracy: 0.3742
# Epoch 89/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7220 - categorical_accuracy: 0.3695 - val_loss: 1.7137 - val_categorical_accuracy: 0.3631
# Epoch 90/100
# 200/199 [==============================] - 61s 306ms/step - loss: 1.7343 - categorical_accuracy: 0.3627 - val_loss: 1.8988 - val_categorical_accuracy: 0.3597
# Epoch 91/100
# 200/199 [==============================] - 61s 307ms/step - loss: 1.7366 - categorical_accuracy: 0.3683 - val_loss: 1.6944 - val_categorical_accuracy: 0.3542
# Epoch 92/100
# 200/199 [==============================] - 61s 306ms/step - loss: 1.7223 - categorical_accuracy: 0.3764 - val_loss: 1.9496 - val_categorical_accuracy: 0.3378
# Epoch 93/100
# 200/199 [==============================] - 62s 310ms/step - loss: 1.7322 - categorical_accuracy: 0.3689 - val_loss: 1.3311 - val_categorical_accuracy: 0.3674
# Epoch 94/100
# 200/199 [==============================] - 62s 309ms/step - loss: 1.7252 - categorical_accuracy: 0.3653 - val_loss: 1.4438 - val_categorical_accuracy: 0.3730
# Epoch 95/100
# 200/199 [==============================] - 62s 309ms/step - loss: 1.7300 - categorical_accuracy: 0.3619 - val_loss: 1.5959 - val_categorical_accuracy: 0.3630
# Epoch 96/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7224 - categorical_accuracy: 0.3747 - val_loss: 1.6632 - val_categorical_accuracy: 0.3664
# Epoch 97/100
# 200/199 [==============================] - 62s 308ms/step - loss: 1.7226 - categorical_accuracy: 0.3719 - val_loss: 1.6890 - val_categorical_accuracy: 0.3833
# Epoch 98/100
# 200/199 [==============================] - 62s 309ms/step - loss: 1.7210 - categorical_accuracy: 0.3694 - val_loss: 1.8844 - val_categorical_accuracy: 0.3655
# Epoch 99/100
# 200/199 [==============================] - 61s 307ms/step - loss: 1.7277 - categorical_accuracy: 0.3728 - val_loss: 1.4084 - val_categorical_accuracy: 0.3831
# Epoch 100/100
# 200/199 [==============================] - 61s 306ms/step - loss: 1.7240 - categorical_accuracy: 0.3719 - val_loss: 1.7073 - val_categorical_accuracy: 0.3850
# Train:
# [1.8039552839879078, 0.3673596978187561]
# Val:
# [1.845885260105133, 0.3387500047683716]

# %% [markdown]
# ### Try using VGG16

# %%
from keras.applications import VGG16

vgg_conv = VGG16(weights='imagenet', include_top=False, input_shape=(128, 400, 3))

for layer in vgg_conv.layers[:-4]:
    layer.trainable = False
    
for layer in vgg_conv.layers:
    print(layer, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f0051d04c18> False
# <keras.layers.convolutional.Conv2D object at 0x7efff9649160> False
# <keras.layers.convolutional.Conv2D object at 0x7efff9649438> False
# <keras.layers.pooling.MaxPooling2D object at 0x7efff96498d0> False
# <keras.layers.convolutional.Conv2D object at 0x7efff96497f0> False
# <keras.layers.convolutional.Conv2D object at 0x7efff956f7f0> False
# <keras.layers.pooling.MaxPooling2D object at 0x7efff957b390> False
# <keras.layers.convolutional.Conv2D object at 0x7efff957b1d0> False
# <keras.layers.convolutional.Conv2D object at 0x7efff957beb8> False
# <keras.layers.convolutional.Conv2D object at 0x7efff9584a58> False
# <keras.layers.pooling.MaxPooling2D object at 0x7efff95904e0> False
# <keras.layers.convolutional.Conv2D object at 0x7efff9590320> False
# <keras.layers.convolutional.Conv2D object at 0x7efff9590fd0> False
# <keras.layers.convolutional.Conv2D object at 0x7efff9574ba8> False
# <keras.layers.pooling.MaxPooling2D object at 0x7efff9599668> False
# <keras.layers.convolutional.Conv2D object at 0x7efff9599470> True
# <keras.layers.convolutional.Conv2D object at 0x7efff9599f98> True
# <keras.layers.convolutional.Conv2D object at 0x7efff959fda0> True
# <keras.layers.pooling.MaxPooling2D object at 0x7efff95f4860> True

# %%
X_train_RGB = X_train.reshape((-1, 128, 400))
X_train_RGB = np.repeat(X_train_RGB[..., np.newaxis], 3, -1)
X_train_RGB.shape
# Out:
# (6397, 128, 400, 3)

# %%
X_val_RGB = X_val.reshape((-1, 128, 400))
X_val_RGB = np.repeat(X_val_RGB[..., np.newaxis], 3, -1)
X_val_RGB.shape
# Out:
# (800, 128, 400, 3)

# %%
model = keras.Sequential()

model.add(vgg_conv)
model.add(Flatten())
model.add(Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2()))
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(lr=0.0001), metrics=['categorical_accuracy'])

mcp_save = ModelCheckpoint('retrained-model-mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=1)
history = model.fit(X_train_RGB, y_train, validation_split=0.1, verbose=1, epochs=20, callbacks=[mcp_save])
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

model = load_model('retrained-model-mel-spec.hdf5')
print('Train:')
print(model.evaluate(X_train_RGB, y_train, verbose=2))
print('Val:')
print(model.evaluate(X_val_RGB, y_val, verbose=2))
# Out:
# Train on 5757 samples, validate on 640 samples
# Epoch 1/20
# 5757/5757 [==============================] - 29s 5ms/step - loss: 2.1288 - categorical_accuracy: 0.1853 - val_loss: 1.7993 - val_categorical_accuracy: 0.3063
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.30625, saving model to retrained-model-mel-spec.hdf5
# Epoch 2/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.9432 - categorical_accuracy: 0.2385 - val_loss: 1.8098 - val_categorical_accuracy: 0.4234
#
# Epoch 00002: val_categorical_accuracy improved from 0.30625 to 0.42344, saving model to retrained-model-mel-spec.hdf5
# Epoch 3/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.8704 - categorical_accuracy: 0.2838 - val_loss: 1.6551 - val_categorical_accuracy: 0.4328
#
# Epoch 00003: val_categorical_accuracy improved from 0.42344 to 0.43281, saving model to retrained-model-mel-spec.hdf5
# Epoch 4/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.8216 - categorical_accuracy: 0.3076 - val_loss: 1.6016 - val_categorical_accuracy: 0.4656
#
# Epoch 00004: val_categorical_accuracy improved from 0.43281 to 0.46562, saving model to retrained-model-mel-spec.hdf5
# Epoch 5/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.7712 - categorical_accuracy: 0.3180 - val_loss: 1.5757 - val_categorical_accuracy: 0.4906
#
# Epoch 00005: val_categorical_accuracy improved from 0.46562 to 0.49062, saving model to retrained-model-mel-spec.hdf5
# Epoch 6/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.7375 - categorical_accuracy: 0.3226 - val_loss: 1.6199 - val_categorical_accuracy: 0.5156
#
# Epoch 00006: val_categorical_accuracy improved from 0.49062 to 0.51562, saving model to retrained-model-mel-spec.hdf5
# Epoch 7/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.6929 - categorical_accuracy: 0.3443 - val_loss: 1.5489 - val_categorical_accuracy: 0.5000
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.51562
# Epoch 8/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.6677 - categorical_accuracy: 0.3504 - val_loss: 1.5271 - val_categorical_accuracy: 0.5031
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.51562
# Epoch 9/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.6166 - categorical_accuracy: 0.3762 - val_loss: 1.5445 - val_categorical_accuracy: 0.4984
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.51562
# Epoch 10/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.5916 - categorical_accuracy: 0.3738 - val_loss: 1.5539 - val_categorical_accuracy: 0.5000
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.51562
# Epoch 11/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.5537 - categorical_accuracy: 0.3960 - val_loss: 1.5297 - val_categorical_accuracy: 0.5031
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.51562
# Epoch 12/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.5210 - categorical_accuracy: 0.4146 - val_loss: 1.5505 - val_categorical_accuracy: 0.5000
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.51562
# Epoch 13/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.4798 - categorical_accuracy: 0.4372 - val_loss: 1.5208 - val_categorical_accuracy: 0.5094
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.51562
# Epoch 14/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.4414 - categorical_accuracy: 0.4485 - val_loss: 1.5232 - val_categorical_accuracy: 0.5156
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.51562
# Epoch 15/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.4086 - categorical_accuracy: 0.4574 - val_loss: 1.5380 - val_categorical_accuracy: 0.5266
#
# Epoch 00015: val_categorical_accuracy improved from 0.51562 to 0.52656, saving model to retrained-model-mel-spec.hdf5
# Epoch 16/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.3574 - categorical_accuracy: 0.4820 - val_loss: 1.6839 - val_categorical_accuracy: 0.4703
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.52656
# Epoch 17/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.3276 - categorical_accuracy: 0.4846 - val_loss: 1.5815 - val_categorical_accuracy: 0.5031
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.52656
# Epoch 18/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.2787 - categorical_accuracy: 0.5022 - val_loss: 1.5999 - val_categorical_accuracy: 0.5250
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.52656
# Epoch 19/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.2548 - categorical_accuracy: 0.5152 - val_loss: 1.6470 - val_categorical_accuracy: 0.4969
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.52656
# Epoch 20/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.2142 - categorical_accuracy: 0.5312 - val_loss: 1.6295 - val_categorical_accuracy: 0.5172
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.52656

# %%
model = load_model('retrained-model-mel-spec.hdf5')
print('Train:')
print(model.evaluate(X_train_RGB, y_train, verbose=2))
print('Val:')
print(model.evaluate(X_val_RGB, y_val, verbose=2))
# Out:
# Train:
# [1.0483733980249796, 0.6915741562843323]
# Val:
# [1.5134249138832092, 0.550000011920929]

# %%
model = keras.Sequential()

model.add(vgg_conv)
model.add(Flatten())
model.add(Dense(8, activation='relu', kernel_regularizer=keras.regularizers.l2()))
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(lr=0.0001), metrics=['categorical_accuracy'])

mcp_save = ModelCheckpoint('retrained-model-mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=1)
history = model.fit(X_train_RGB, y_train, validation_split=0.1, verbose=1, epochs=20, callbacks=[mcp_save])
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

model = load_model('retrained-model-mel-spec.hdf5')
print('Train:')
print(model.evaluate(X_train_RGB, y_train, verbose=2))
print('Val:')
print(model.evaluate(X_val_RGB, y_val, verbose=2))
# Out:
# Train on 5757 samples, validate on 640 samples
# Epoch 1/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.9564 - categorical_accuracy: 0.2920 - val_loss: 1.8582 - val_categorical_accuracy: 0.4187
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.41875, saving model to retrained-model-mel-spec.hdf5
# Epoch 2/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.7466 - categorical_accuracy: 0.3761 - val_loss: 1.8395 - val_categorical_accuracy: 0.4484
#
# Epoch 00002: val_categorical_accuracy improved from 0.41875 to 0.44844, saving model to retrained-model-mel-spec.hdf5
# Epoch 3/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.6573 - categorical_accuracy: 0.4120 - val_loss: 1.8719 - val_categorical_accuracy: 0.4328
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.44844
# Epoch 4/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.5757 - categorical_accuracy: 0.4353 - val_loss: 1.7109 - val_categorical_accuracy: 0.3656
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.44844
# Epoch 5/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.4726 - categorical_accuracy: 0.4537 - val_loss: 1.6877 - val_categorical_accuracy: 0.4719
#
# Epoch 00005: val_categorical_accuracy improved from 0.44844 to 0.47188, saving model to retrained-model-mel-spec.hdf5
# Epoch 6/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.4150 - categorical_accuracy: 0.4914 - val_loss: 1.6800 - val_categorical_accuracy: 0.5047
#
# Epoch 00006: val_categorical_accuracy improved from 0.47188 to 0.50469, saving model to retrained-model-mel-spec.hdf5
# Epoch 7/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.3627 - categorical_accuracy: 0.5072 - val_loss: 1.7117 - val_categorical_accuracy: 0.4781
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.50469
# Epoch 8/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.3143 - categorical_accuracy: 0.5164 - val_loss: 1.7377 - val_categorical_accuracy: 0.5094
#
# Epoch 00008: val_categorical_accuracy improved from 0.50469 to 0.50937, saving model to retrained-model-mel-spec.hdf5
# Epoch 9/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.2730 - categorical_accuracy: 0.5310 - val_loss: 1.6952 - val_categorical_accuracy: 0.5141
#
# Epoch 00009: val_categorical_accuracy improved from 0.50937 to 0.51406, saving model to retrained-model-mel-spec.hdf5
# Epoch 10/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.2195 - categorical_accuracy: 0.5385 - val_loss: 1.6863 - val_categorical_accuracy: 0.5109
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.51406
# Epoch 11/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.1759 - categorical_accuracy: 0.5416 - val_loss: 1.6891 - val_categorical_accuracy: 0.5219
#
# Epoch 00011: val_categorical_accuracy improved from 0.51406 to 0.52188, saving model to retrained-model-mel-spec.hdf5
# Epoch 12/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.1444 - categorical_accuracy: 0.5491 - val_loss: 1.9054 - val_categorical_accuracy: 0.5250
#
# Epoch 00012: val_categorical_accuracy improved from 0.52188 to 0.52500, saving model to retrained-model-mel-spec.hdf5
# Epoch 13/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.1361 - categorical_accuracy: 0.5435 - val_loss: 1.8292 - val_categorical_accuracy: 0.4938
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.52500
# Epoch 14/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.1238 - categorical_accuracy: 0.5574 - val_loss: 1.8474 - val_categorical_accuracy: 0.4828
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.52500
# Epoch 15/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.1044 - categorical_accuracy: 0.5656 - val_loss: 1.8577 - val_categorical_accuracy: 0.5125
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.52500
# Epoch 16/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.0772 - categorical_accuracy: 0.5710 - val_loss: 1.8330 - val_categorical_accuracy: 0.5031
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.52500
# Epoch 17/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.0325 - categorical_accuracy: 0.5887 - val_loss: 1.9277 - val_categorical_accuracy: 0.4875
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.52500
# Epoch 18/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.0209 - categorical_accuracy: 0.5868 - val_loss: 1.9054 - val_categorical_accuracy: 0.4703
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.52500
# Epoch 19/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.0089 - categorical_accuracy: 0.5885 - val_loss: 1.9529 - val_categorical_accuracy: 0.5141
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.52500
# Epoch 20/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.9765 - categorical_accuracy: 0.6095 - val_loss: 1.9797 - val_categorical_accuracy: 0.5156
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.52500
# Train:
# [0.7418744224895998, 0.7867750525474548]
# Val:
# [1.9234111356735228, 0.5475000143051147]

# %%
model = keras.Sequential()

model.add(vgg_conv)
model.add(Flatten())
model.add(Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l1()))
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(lr=0.0001), metrics=['categorical_accuracy'])

mcp_save = ModelCheckpoint('retrained-model-mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=1)
history = model.fit(X_train_RGB, y_train, validation_split=0.1, verbose=1, epochs=20, callbacks=[mcp_save])
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

model = load_model('retrained-model-mel-spec.hdf5')
print('Train:')
print(model.evaluate(X_train_RGB, y_train, verbose=2))
print('Val:')
print(model.evaluate(X_val_RGB, y_val, verbose=2))
# Out:
# Train on 5757 samples, validate on 640 samples
# Epoch 1/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 14.6678 - categorical_accuracy: 0.5202 - val_loss: 5.7221 - val_categorical_accuracy: 0.5234
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.52344, saving model to retrained-model-mel-spec.hdf5
# Epoch 2/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 3.4452 - categorical_accuracy: 0.6608 - val_loss: 3.1046 - val_categorical_accuracy: 0.5250
#
# Epoch 00002: val_categorical_accuracy improved from 0.52344 to 0.52500, saving model to retrained-model-mel-spec.hdf5
# Epoch 3/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.9690 - categorical_accuracy: 0.6719 - val_loss: 2.4459 - val_categorical_accuracy: 0.5203
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.52500
# Epoch 4/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.5714 - categorical_accuracy: 0.6830 - val_loss: 2.2864 - val_categorical_accuracy: 0.5391
#
# Epoch 00004: val_categorical_accuracy improved from 0.52500 to 0.53906, saving model to retrained-model-mel-spec.hdf5
# Epoch 5/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.4313 - categorical_accuracy: 0.6955 - val_loss: 2.1580 - val_categorical_accuracy: 0.5281
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.53906
# Epoch 6/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.3039 - categorical_accuracy: 0.7115 - val_loss: 2.1297 - val_categorical_accuracy: 0.5375
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.53906
# Epoch 7/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.2630 - categorical_accuracy: 0.7195 - val_loss: 2.2314 - val_categorical_accuracy: 0.5312
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.53906
# Epoch 8/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.2006 - categorical_accuracy: 0.7195 - val_loss: 2.2044 - val_categorical_accuracy: 0.5281
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.53906
# Epoch 9/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.1319 - categorical_accuracy: 0.7457 - val_loss: 2.1495 - val_categorical_accuracy: 0.5125
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.53906
# Epoch 10/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.0668 - categorical_accuracy: 0.7657 - val_loss: 2.3558 - val_categorical_accuracy: 0.5281
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.53906
# Epoch 11/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.0507 - categorical_accuracy: 0.7573 - val_loss: 2.4753 - val_categorical_accuracy: 0.5391
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.53906
# Epoch 12/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.9948 - categorical_accuracy: 0.7752 - val_loss: 2.3107 - val_categorical_accuracy: 0.5406
#
# Epoch 00012: val_categorical_accuracy improved from 0.53906 to 0.54062, saving model to retrained-model-mel-spec.hdf5
# Epoch 13/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.9596 - categorical_accuracy: 0.7853 - val_loss: 2.1447 - val_categorical_accuracy: 0.5312
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.54062
# Epoch 14/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.9406 - categorical_accuracy: 0.7851 - val_loss: 2.2789 - val_categorical_accuracy: 0.5297
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.54062
# Epoch 15/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.9106 - categorical_accuracy: 0.7949 - val_loss: 2.2279 - val_categorical_accuracy: 0.5203
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.54062
# Epoch 16/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.8573 - categorical_accuracy: 0.8119 - val_loss: 2.5210 - val_categorical_accuracy: 0.5141
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.54062
# Epoch 17/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.8290 - categorical_accuracy: 0.8190 - val_loss: 2.5796 - val_categorical_accuracy: 0.4984
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.54062
# Epoch 18/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.8097 - categorical_accuracy: 0.8242 - val_loss: 2.4019 - val_categorical_accuracy: 0.5078
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.54062
# Epoch 19/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.7734 - categorical_accuracy: 0.8308 - val_loss: 2.6828 - val_categorical_accuracy: 0.5125
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.54062
# Epoch 20/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.7486 - categorical_accuracy: 0.8329 - val_loss: 2.5000 - val_categorical_accuracy: 0.5312
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.54062
# Train:
# [0.8022680784997408, 0.9119899868965149]
# Val:
# [2.286885743141174, 0.5287500023841858]

# %%
model = keras.Sequential()

model.add(vgg_conv)
model.add(Flatten())
model.add(Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l1_l2()))
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(lr=0.0001), metrics=['categorical_accuracy'])

mcp_save = ModelCheckpoint('retrained-model-mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=1)
history = model.fit(X_train_RGB, y_train, validation_split=0.1, verbose=1, epochs=20, callbacks=[mcp_save])
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

model = load_model('retrained-model-mel-spec.hdf5')
print('Train:')
print(model.evaluate(X_train_RGB, y_train, verbose=2))
print('Val:')
print(model.evaluate(X_val_RGB, y_val, verbose=2))
# Out:
# Train on 5757 samples, validate on 640 samples
# Epoch 1/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 12.7724 - categorical_accuracy: 0.5776 - val_loss: 4.6243 - val_categorical_accuracy: 0.5172
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.51719, saving model to retrained-model-mel-spec.hdf5
# Epoch 2/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 2.5240 - categorical_accuracy: 0.7705 - val_loss: 3.3559 - val_categorical_accuracy: 0.5188
#
# Epoch 00002: val_categorical_accuracy improved from 0.51719 to 0.51875, saving model to retrained-model-mel-spec.hdf5
# Epoch 3/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.5719 - categorical_accuracy: 0.8011 - val_loss: 2.8393 - val_categorical_accuracy: 0.4953
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.51875
# Epoch 4/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.1916 - categorical_accuracy: 0.8147 - val_loss: 2.7086 - val_categorical_accuracy: 0.5266
#
# Epoch 00004: val_categorical_accuracy improved from 0.51875 to 0.52656, saving model to retrained-model-mel-spec.hdf5
# Epoch 5/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 1.0046 - categorical_accuracy: 0.8282 - val_loss: 2.5223 - val_categorical_accuracy: 0.5203
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.52656
# Epoch 6/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.8794 - categorical_accuracy: 0.8477 - val_loss: 2.5417 - val_categorical_accuracy: 0.5078
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.52656
# Epoch 7/20
# 5757/5757 [==============================] - 21s 4ms/step - loss: 0.8017 - categorical_accuracy: 0.8572 - val_loss: 2.6422 - val_categorical_accuracy: 0.5109
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.52656
# Epoch 8/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.7625 - categorical_accuracy: 0.8640 - val_loss: 2.3715 - val_categorical_accuracy: 0.5172
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.52656
# Epoch 9/20
# 5757/5757 [==============================] - 21s 4ms/step - loss: 0.7234 - categorical_accuracy: 0.8652 - val_loss: 2.6524 - val_categorical_accuracy: 0.5250
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.52656
# Epoch 10/20
# 5757/5757 [==============================] - 21s 4ms/step - loss: 0.7036 - categorical_accuracy: 0.8687 - val_loss: 2.5989 - val_categorical_accuracy: 0.5266
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.52656
# Epoch 11/20
# 5757/5757 [==============================] - 21s 4ms/step - loss: 0.7013 - categorical_accuracy: 0.8678 - val_loss: 2.6005 - val_categorical_accuracy: 0.5234
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.52656
# Epoch 12/20
# 5757/5757 [==============================] - 21s 4ms/step - loss: 0.6705 - categorical_accuracy: 0.8723 - val_loss: 2.8521 - val_categorical_accuracy: 0.5000
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.52656
# Epoch 13/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.7041 - categorical_accuracy: 0.8746 - val_loss: 2.8440 - val_categorical_accuracy: 0.5078
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.52656
# Epoch 14/20
# 5757/5757 [==============================] - 21s 4ms/step - loss: 0.6476 - categorical_accuracy: 0.8795 - val_loss: 2.6663 - val_categorical_accuracy: 0.5063
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.52656
# Epoch 15/20
# 5757/5757 [==============================] - 21s 4ms/step - loss: 0.6322 - categorical_accuracy: 0.8821 - val_loss: 2.5844 - val_categorical_accuracy: 0.5188
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.52656
# Epoch 16/20
# 5757/5757 [==============================] - 21s 4ms/step - loss: 0.6125 - categorical_accuracy: 0.8843 - val_loss: 2.6989 - val_categorical_accuracy: 0.5156
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.52656
# Epoch 17/20
# 5757/5757 [==============================] - 21s 4ms/step - loss: 0.6087 - categorical_accuracy: 0.8864 - val_loss: 2.7594 - val_categorical_accuracy: 0.5172
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.52656
# Epoch 18/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.5841 - categorical_accuracy: 0.8913 - val_loss: 2.6711 - val_categorical_accuracy: 0.5109
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.52656
# Epoch 19/20
# 5757/5757 [==============================] - 22s 4ms/step - loss: 0.6063 - categorical_accuracy: 0.8874 - val_loss: 2.7121 - val_categorical_accuracy: 0.5234
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.52656
# Epoch 20/20
# 5757/5757 [==============================] - 21s 4ms/step - loss: 0.5968 - categorical_accuracy: 0.8900 - val_loss: 2.7993 - val_categorical_accuracy: 0.5156
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.52656
# Train:
# [0.8997822296103221, 0.9357511401176453]
# Val:
# [2.936539263725281, 0.5099999904632568]

# %% [markdown]
# ### Using VGG with best parameters and ImageDataGenerator

# %%
from keras.applications import VGG16

vgg_conv = VGG16(weights='imagenet', include_top=False, input_shape=(128, 400, 3))

for layer in vgg_conv.layers[:-4]:
    layer.trainable = False
    
for layer in vgg_conv.layers:
    print(layer, layer.trainable)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 5s 0us/step
# <keras.engine.input_layer.InputLayer object at 0x7f50eb052048> False
# <keras.layers.convolutional.Conv2D object at 0x7f50eb052668> False
# <keras.layers.convolutional.Conv2D object at 0x7f50ef53d198> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f50eb052d30> False
# <keras.layers.convolutional.Conv2D object at 0x7f50eb052e80> False
# <keras.layers.convolutional.Conv2D object at 0x7f50eb21fbe0> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f50eb22d780> False
# <keras.layers.convolutional.Conv2D object at 0x7f50eb22d5c0> False
# <keras.layers.convolutional.Conv2D object at 0x7f50eb2382e8> False
# <keras.layers.convolutional.Conv2D object at 0x7f50eb238e48> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f50eb23d8d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f50eb23d710> False
# <keras.layers.convolutional.Conv2D object at 0x7f50eb245400> False
# <keras.layers.convolutional.Conv2D object at 0x7f50eb245dd8> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f50eb254a20> False
# <keras.layers.convolutional.Conv2D object at 0x7f50eb254860> True
# <keras.layers.convolutional.Conv2D object at 0x7f50eb25d550> True
# <keras.layers.convolutional.Conv2D object at 0x7f50eb25de48> True
# <keras.layers.pooling.MaxPooling2D object at 0x7f50eaf67b70> True

# %%
X_train_RGB = X_train.reshape((-1, 128, 400))
X_train_RGB = np.repeat(X_train_RGB[..., np.newaxis], 3, -1)
X_train_RGB.shape
# Out:
# (6397, 128, 400, 3)

# %%
X_val_RGB = X_val.reshape((-1, 128, 400))
X_val_RGB = np.repeat(X_val_RGB[..., np.newaxis], 3, -1)
X_val_RGB.shape
# Out:
# (800, 128, 400, 3)

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rotation_range=20, width_shift_range=0.2, height_shift_range=0.2, horizontal_flip=True, fill_mode='nearest')
train_batchsize = 32
val_batchsize = 16
val_datagen = ImageDataGenerator()

train_generator = train_datagen.flow(X_train_RGB, y_train, batch_size=train_batchsize)
#val_generator = train_datagen.flow(X_train_RGB, y_train, batch_size=val_batchsize, subset='validation')

# %%
model = keras.Sequential()

model.add(vgg_conv)
model.add(Flatten())
model.add(Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2()))
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(lr=0.0001), metrics=['categorical_accuracy'])

mcp_save = ModelCheckpoint('retrained-model-mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(train_generator, steps_per_epoch=len(X_train)/ train_batchsize, epochs=50, validation_data=(X_val_RGB, y_val), callbacks=[mcp_save])
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

model = load_model('retrained-model-mel-spec.hdf5')
print('Train:')
print(model.evaluate(X_train_RGB, y_train, verbose=2))
print('Val:')
print(model.evaluate(X_val_RGB, y_val, verbose=2))
# Out:
# Epoch 1/50
# 200/199 [==============================] - 68s 340ms/step - loss: 2.1896 - categorical_accuracy: 0.1510 - val_loss: 2.1289 - val_categorical_accuracy: 0.1462
# Epoch 2/50
# 200/199 [==============================] - 62s 311ms/step - loss: 2.0953 - categorical_accuracy: 0.1779 - val_loss: 1.9928 - val_categorical_accuracy: 0.3000
# Epoch 3/50
# 200/199 [==============================] - 62s 308ms/step - loss: 2.0342 - categorical_accuracy: 0.2009 - val_loss: 1.9581 - val_categorical_accuracy: 0.3063
# Epoch 4/50
# 200/199 [==============================] - 62s 312ms/step - loss: 2.0045 - categorical_accuracy: 0.2178 - val_loss: 1.8846 - val_categorical_accuracy: 0.3450
# Epoch 5/50
# 200/199 [==============================] - 62s 308ms/step - loss: 1.9869 - categorical_accuracy: 0.2093 - val_loss: 1.8983 - val_categorical_accuracy: 0.3762
# Epoch 6/50
# 200/199 [==============================] - 61s 307ms/step - loss: 1.9659 - categorical_accuracy: 0.2270 - val_loss: 1.8511 - val_categorical_accuracy: 0.3787
# Epoch 7/50
# 200/199 [==============================] - 62s 308ms/step - loss: 1.9212 - categorical_accuracy: 0.2543 - val_loss: 1.7659 - val_categorical_accuracy: 0.3938
# Epoch 8/50
# 200/199 [==============================] - 61s 304ms/step - loss: 1.8644 - categorical_accuracy: 0.2917 - val_loss: 1.7516 - val_categorical_accuracy: 0.4400
# Epoch 9/50
# 200/199 [==============================] - 61s 306ms/step - loss: 1.8486 - categorical_accuracy: 0.3020 - val_loss: 1.7408 - val_categorical_accuracy: 0.4275
# Epoch 10/50
# 200/199 [==============================] - 61s 304ms/step - loss: 1.8143 - categorical_accuracy: 0.3205 - val_loss: 1.6422 - val_categorical_accuracy: 0.4350
# Epoch 11/50
# 200/199 [==============================] - 60s 301ms/step - loss: 1.7710 - categorical_accuracy: 0.3448 - val_loss: 1.5991 - val_categorical_accuracy: 0.4712
# Epoch 12/50
# 200/199 [==============================] - 61s 307ms/step - loss: 1.7577 - categorical_accuracy: 0.3469 - val_loss: 1.6160 - val_categorical_accuracy: 0.4638
# Epoch 13/50
# 200/199 [==============================] - 61s 303ms/step - loss: 1.7283 - categorical_accuracy: 0.3730 - val_loss: 1.5976 - val_categorical_accuracy: 0.4538
# Epoch 14/50
# 200/199 [==============================] - 61s 303ms/step - loss: 1.7059 - categorical_accuracy: 0.3813 - val_loss: 1.6154 - val_categorical_accuracy: 0.4325
# Epoch 15/50
# 200/199 [==============================] - 61s 303ms/step - loss: 1.6955 - categorical_accuracy: 0.3910 - val_loss: 1.5674 - val_categorical_accuracy: 0.4875
# Epoch 16/50
# 200/199 [==============================] - 60s 300ms/step - loss: 1.6817 - categorical_accuracy: 0.3896 - val_loss: 1.5554 - val_categorical_accuracy: 0.5138
# Epoch 17/50
# 200/199 [==============================] - 60s 302ms/step - loss: 1.6648 - categorical_accuracy: 0.4055 - val_loss: 1.5075 - val_categorical_accuracy: 0.5063
# Epoch 18/50
# 200/199 [==============================] - 60s 301ms/step - loss: 1.6484 - categorical_accuracy: 0.4050 - val_loss: 1.5463 - val_categorical_accuracy: 0.4525
# Epoch 19/50
# 200/199 [==============================] - 61s 303ms/step - loss: 1.6381 - categorical_accuracy: 0.4085 - val_loss: 1.5488 - val_categorical_accuracy: 0.4900
# Epoch 20/50
# 200/199 [==============================] - 60s 302ms/step - loss: 1.6081 - categorical_accuracy: 0.4219 - val_loss: 1.4482 - val_categorical_accuracy: 0.5462
# Epoch 21/50
# 200/199 [==============================] - 60s 301ms/step - loss: 1.5889 - categorical_accuracy: 0.4321 - val_loss: 1.5075 - val_categorical_accuracy: 0.5125
# Epoch 22/50
# 200/199 [==============================] - 61s 304ms/step - loss: 1.5866 - categorical_accuracy: 0.4382 - val_loss: 1.4381 - val_categorical_accuracy: 0.5375
# Epoch 23/50
# 200/199 [==============================] - 61s 304ms/step - loss: 1.5764 - categorical_accuracy: 0.4490 - val_loss: 1.4721 - val_categorical_accuracy: 0.5350
# Epoch 24/50
# 200/199 [==============================] - 61s 303ms/step - loss: 1.5452 - categorical_accuracy: 0.4474 - val_loss: 1.4581 - val_categorical_accuracy: 0.5250
# Epoch 25/50
# 200/199 [==============================] - 60s 302ms/step - loss: 1.5387 - categorical_accuracy: 0.4511 - val_loss: 1.5283 - val_categorical_accuracy: 0.4850
# Epoch 26/50
# 200/199 [==============================] - 61s 304ms/step - loss: 1.5325 - categorical_accuracy: 0.4468 - val_loss: 1.4256 - val_categorical_accuracy: 0.5275
# Epoch 27/50
# 200/199 [==============================] - 60s 301ms/step - loss: 1.5339 - categorical_accuracy: 0.4532 - val_loss: 1.4714 - val_categorical_accuracy: 0.4975
# Epoch 28/50
# 200/199 [==============================] - 60s 302ms/step - loss: 1.5103 - categorical_accuracy: 0.4680 - val_loss: 1.5052 - val_categorical_accuracy: 0.5113
# Epoch 29/50
# 200/199 [==============================] - 61s 304ms/step - loss: 1.5080 - categorical_accuracy: 0.4580 - val_loss: 1.4861 - val_categorical_accuracy: 0.5175
# Epoch 30/50
# 200/199 [==============================] - 60s 301ms/step - loss: 1.4931 - categorical_accuracy: 0.4616 - val_loss: 1.4463 - val_categorical_accuracy: 0.5275
# Epoch 31/50
# 200/199 [==============================] - 60s 302ms/step - loss: 1.4719 - categorical_accuracy: 0.4687 - val_loss: 1.4788 - val_categorical_accuracy: 0.5200
# Epoch 32/50
# 200/199 [==============================] - 61s 303ms/step - loss: 1.4922 - categorical_accuracy: 0.4671 - val_loss: 1.5446 - val_categorical_accuracy: 0.5412
# Epoch 33/50
# 200/199 [==============================] - 60s 302ms/step - loss: 1.4524 - categorical_accuracy: 0.4837 - val_loss: 1.4702 - val_categorical_accuracy: 0.5462
# Epoch 34/50
# 200/199 [==============================] - 61s 303ms/step - loss: 1.4451 - categorical_accuracy: 0.4854 - val_loss: 1.6774 - val_categorical_accuracy: 0.4550
# Epoch 35/50
# 200/199 [==============================] - 60s 302ms/step - loss: 1.4508 - categorical_accuracy: 0.4855 - val_loss: 1.4684 - val_categorical_accuracy: 0.5475
# Epoch 36/50
# 200/199 [==============================] - 61s 304ms/step - loss: 1.4475 - categorical_accuracy: 0.4862 - val_loss: 1.5006 - val_categorical_accuracy: 0.5250
# Epoch 37/50
# 200/199 [==============================] - 61s 305ms/step - loss: 1.4270 - categorical_accuracy: 0.4921 - val_loss: 1.4519 - val_categorical_accuracy: 0.5487
# Epoch 38/50
# 200/199 [==============================] - 60s 299ms/step - loss: 1.4200 - categorical_accuracy: 0.5005 - val_loss: 1.4726 - val_categorical_accuracy: 0.5325
# Epoch 39/50
# 200/199 [==============================] - 60s 301ms/step - loss: 1.3942 - categorical_accuracy: 0.4954 - val_loss: 1.5400 - val_categorical_accuracy: 0.5300
# Epoch 40/50
# 200/199 [==============================] - 60s 302ms/step - loss: 1.4075 - categorical_accuracy: 0.4948 - val_loss: 1.6261 - val_categorical_accuracy: 0.5025
# Epoch 41/50
# 200/199 [==============================] - 60s 301ms/step - loss: 1.3737 - categorical_accuracy: 0.5154 - val_loss: 1.7465 - val_categorical_accuracy: 0.4663
# Epoch 42/50
# 200/199 [==============================] - 61s 304ms/step - loss: 1.3870 - categorical_accuracy: 0.5065 - val_loss: 1.5032 - val_categorical_accuracy: 0.5312
# Epoch 43/50
# 200/199 [==============================] - 60s 301ms/step - loss: 1.3649 - categorical_accuracy: 0.5156 - val_loss: 1.5024 - val_categorical_accuracy: 0.5362
# Epoch 44/50
# 200/199 [==============================] - 60s 301ms/step - loss: 1.3629 - categorical_accuracy: 0.5166 - val_loss: 1.4691 - val_categorical_accuracy: 0.5038
# Epoch 45/50
# 200/199 [==============================] - 60s 301ms/step - loss: 1.3416 - categorical_accuracy: 0.5160 - val_loss: 1.5676 - val_categorical_accuracy: 0.5450
# Epoch 46/50
# 200/199 [==============================] - 60s 302ms/step - loss: 1.3442 - categorical_accuracy: 0.5163 - val_loss: 1.5250 - val_categorical_accuracy: 0.5238
# Epoch 47/50
# 200/199 [==============================] - 60s 301ms/step - loss: 1.3258 - categorical_accuracy: 0.5206 - val_loss: 1.5212 - val_categorical_accuracy: 0.5213
# Epoch 48/50
# 200/199 [==============================] - 60s 302ms/step - loss: 1.3405 - categorical_accuracy: 0.5238 - val_loss: 1.5593 - val_categorical_accuracy: 0.5200
# Epoch 49/50
# 200/199 [==============================] - 60s 299ms/step - loss: 1.3161 - categorical_accuracy: 0.5348 - val_loss: 1.6244 - val_categorical_accuracy: 0.5175
# Epoch 50/50
# 200/199 [==============================] - 60s 300ms/step - loss: 1.2989 - categorical_accuracy: 0.5331 - val_loss: 1.4983 - val_categorical_accuracy: 0.5213
# Train:
# [1.1900609385805128, 0.6120056509971619]
# Val:
# [1.4518801546096802, 0.5487499833106995]

# %%
from sklearn.metrics import classification_report

model = load_model('retrained-model-mel-spec.hdf5')
X_test_RGB = X_test.reshape((-1, 128, 400))
X_test_RGB = np.repeat(X_test_RGB[..., np.newaxis], 3, -1)
y_pred = model.predict(X_test_RGB)
y_pred = np.argmax(y_pred, 1)

y_pred = le.inverse_transform(y_pred)
y_true_test = np.argmax(y_test, 1)
y_true_test = le.inverse_transform(y_true_test)

print(classification_report(y_true_test, y_pred))
# Out:
#                precision    recall  f1-score   support
#
#    Electronic       0.34      0.69      0.46       100
#  Experimental       0.30      0.25      0.27       100
#          Folk       0.27      0.29      0.28       100
#       Hip-Hop       0.63      0.74      0.68       100
#  Instrumental       0.48      0.35      0.40       100
# International       0.53      0.51      0.52       100
#           Pop       0.26      0.10      0.14       100
#          Rock       0.65      0.53      0.58       100
#
#      accuracy                           0.43       800
#     macro avg       0.43      0.43      0.42       800
#  weighted avg       0.43      0.43      0.42       800

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

mat = confusion_matrix(y_true_test, y_pred)
plt.figure(figsize=(10,10))

dict_genres = {'Electronic': 0, 'Experimental': 1, 'Folk': 2, 'Hip-Hop': 3, 'Instrumental': 4, 'International': 5, 'Pop': 6, 'Rock': 7}

sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            cmap=sns.cubehelix_palette(8, start=.5, rot=-.75),
            xticklabels=dict_genres.keys(),
            yticklabels=dict_genres.keys())
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Text(76.2, 0.5, 'predicted label')

# %%
model = keras.Sequential()

model.add(vgg_conv)
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(16, activation='relu', kernel_regularizer=keras.regularizers.l2()))
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(lr=0.0001), metrics=['categorical_accuracy'])

mcp_save = ModelCheckpoint('retrained-model-mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(train_generator, steps_per_epoch=len(X_train)/ train_batchsize, epochs=50, validation_data=(X_val_RGB, y_val), callbacks=[mcp_save])
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

model = load_model('retrained-model-mel-spec.hdf5')
print('Train:')
print(model.evaluate(X_train_RGB, y_train, verbose=2))
print('Val:')
print(model.evaluate(X_val_RGB, y_val, verbose=2))
# Out:
# Epoch 1/50
# 200/199 [==============================] - 80s 399ms/step - loss: 2.2253 - categorical_accuracy: 0.1301 - val_loss: 2.1532 - val_categorical_accuracy: 0.1363
# Epoch 2/50
# 200/199 [==============================] - 73s 367ms/step - loss: 2.1418 - categorical_accuracy: 0.1280 - val_loss: 2.1066 - val_categorical_accuracy: 0.1800
# Epoch 3/50
# 200/199 [==============================] - 73s 367ms/step - loss: 2.1016 - categorical_accuracy: 0.1602 - val_loss: 2.0891 - val_categorical_accuracy: 0.1975
# Epoch 4/50
# 200/199 [==============================] - 74s 368ms/step - loss: 2.0690 - categorical_accuracy: 0.1946 - val_loss: 1.9970 - val_categorical_accuracy: 0.2850
# Epoch 5/50
# 200/199 [==============================] - 73s 367ms/step - loss: 2.0099 - categorical_accuracy: 0.2425 - val_loss: 1.9566 - val_categorical_accuracy: 0.2775
# Epoch 6/50
# 200/199 [==============================] - 73s 365ms/step - loss: 1.9742 - categorical_accuracy: 0.2661 - val_loss: 1.9272 - val_categorical_accuracy: 0.3250
# Epoch 7/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.9439 - categorical_accuracy: 0.2828 - val_loss: 1.8734 - val_categorical_accuracy: 0.3638
# Epoch 8/50
# 200/199 [==============================] - 73s 365ms/step - loss: 1.9199 - categorical_accuracy: 0.2953 - val_loss: 1.8756 - val_categorical_accuracy: 0.3925
# Epoch 9/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.8908 - categorical_accuracy: 0.3159 - val_loss: 1.8012 - val_categorical_accuracy: 0.4313
# Epoch 10/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.8803 - categorical_accuracy: 0.3209 - val_loss: 1.8095 - val_categorical_accuracy: 0.4200
# Epoch 11/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.8460 - categorical_accuracy: 0.3445 - val_loss: 1.7262 - val_categorical_accuracy: 0.4863
# Epoch 12/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.7933 - categorical_accuracy: 0.3588 - val_loss: 1.7074 - val_categorical_accuracy: 0.4425
# Epoch 13/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.7504 - categorical_accuracy: 0.3669 - val_loss: 1.6331 - val_categorical_accuracy: 0.4925
# Epoch 14/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.7083 - categorical_accuracy: 0.3882 - val_loss: 1.6042 - val_categorical_accuracy: 0.4712
# Epoch 15/50
# 200/199 [==============================] - 73s 364ms/step - loss: 1.7031 - categorical_accuracy: 0.4000 - val_loss: 1.6595 - val_categorical_accuracy: 0.4750
# Epoch 16/50
# 200/199 [==============================] - 73s 365ms/step - loss: 1.6745 - categorical_accuracy: 0.4130 - val_loss: 1.5501 - val_categorical_accuracy: 0.4913
# Epoch 17/50
# 200/199 [==============================] - 73s 365ms/step - loss: 1.6602 - categorical_accuracy: 0.4152 - val_loss: 1.5314 - val_categorical_accuracy: 0.4938
# Epoch 18/50
# 200/199 [==============================] - 73s 363ms/step - loss: 1.6461 - categorical_accuracy: 0.4191 - val_loss: 1.5088 - val_categorical_accuracy: 0.5113
# Epoch 19/50
# 200/199 [==============================] - 73s 365ms/step - loss: 1.6063 - categorical_accuracy: 0.4340 - val_loss: 1.5252 - val_categorical_accuracy: 0.5113
# Epoch 20/50
# 200/199 [==============================] - 73s 366ms/step - loss: 1.5930 - categorical_accuracy: 0.4415 - val_loss: 1.4929 - val_categorical_accuracy: 0.5238
# Epoch 21/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.5793 - categorical_accuracy: 0.4394 - val_loss: 1.5031 - val_categorical_accuracy: 0.4950
# Epoch 22/50
# 200/199 [==============================] - 73s 364ms/step - loss: 1.5552 - categorical_accuracy: 0.4563 - val_loss: 1.4955 - val_categorical_accuracy: 0.5200
# Epoch 23/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.5427 - categorical_accuracy: 0.4607 - val_loss: 1.4297 - val_categorical_accuracy: 0.5362
# Epoch 24/50
# 200/199 [==============================] - 73s 366ms/step - loss: 1.5401 - categorical_accuracy: 0.4694 - val_loss: 1.4656 - val_categorical_accuracy: 0.5275
# Epoch 25/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.5144 - categorical_accuracy: 0.4733 - val_loss: 1.5020 - val_categorical_accuracy: 0.5113
# Epoch 26/50
# 200/199 [==============================] - 74s 370ms/step - loss: 1.5198 - categorical_accuracy: 0.4732 - val_loss: 1.4831 - val_categorical_accuracy: 0.5275
# Epoch 27/50
# 200/199 [==============================] - 73s 366ms/step - loss: 1.5130 - categorical_accuracy: 0.4787 - val_loss: 1.4860 - val_categorical_accuracy: 0.5213
# Epoch 28/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.4973 - categorical_accuracy: 0.4780 - val_loss: 1.5021 - val_categorical_accuracy: 0.5225
# Epoch 29/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.4790 - categorical_accuracy: 0.4912 - val_loss: 1.5223 - val_categorical_accuracy: 0.5100
# Epoch 30/50
# 200/199 [==============================] - 74s 369ms/step - loss: 1.4645 - categorical_accuracy: 0.4938 - val_loss: 1.4527 - val_categorical_accuracy: 0.5325
# Epoch 31/50
# 200/199 [==============================] - 74s 369ms/step - loss: 1.4568 - categorical_accuracy: 0.4976 - val_loss: 1.4495 - val_categorical_accuracy: 0.5150
# Epoch 32/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.4508 - categorical_accuracy: 0.5018 - val_loss: 1.4444 - val_categorical_accuracy: 0.5113
# Epoch 33/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.4367 - categorical_accuracy: 0.5048 - val_loss: 1.4329 - val_categorical_accuracy: 0.5188
# Epoch 34/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.4167 - categorical_accuracy: 0.5127 - val_loss: 1.5077 - val_categorical_accuracy: 0.5100
# Epoch 35/50
# 200/199 [==============================] - 73s 366ms/step - loss: 1.4123 - categorical_accuracy: 0.5157 - val_loss: 1.4870 - val_categorical_accuracy: 0.5100
# Epoch 36/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.3905 - categorical_accuracy: 0.5212 - val_loss: 1.4892 - val_categorical_accuracy: 0.5050
# Epoch 37/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.3919 - categorical_accuracy: 0.5271 - val_loss: 1.4879 - val_categorical_accuracy: 0.5088
# Epoch 38/50
# 200/199 [==============================] - 73s 364ms/step - loss: 1.3926 - categorical_accuracy: 0.5218 - val_loss: 1.5384 - val_categorical_accuracy: 0.5038
# Epoch 39/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.3728 - categorical_accuracy: 0.5346 - val_loss: 1.5804 - val_categorical_accuracy: 0.4988
# Epoch 40/50
# 200/199 [==============================] - 73s 366ms/step - loss: 1.3683 - categorical_accuracy: 0.5310 - val_loss: 1.6016 - val_categorical_accuracy: 0.4675
# Epoch 41/50
# 200/199 [==============================] - 73s 365ms/step - loss: 1.3464 - categorical_accuracy: 0.5401 - val_loss: 1.6153 - val_categorical_accuracy: 0.4975
# Epoch 42/50
# 200/199 [==============================] - 73s 366ms/step - loss: 1.3479 - categorical_accuracy: 0.5379 - val_loss: 1.5595 - val_categorical_accuracy: 0.5225
# Epoch 43/50
# 200/199 [==============================] - 73s 365ms/step - loss: 1.3446 - categorical_accuracy: 0.5462 - val_loss: 1.5503 - val_categorical_accuracy: 0.5088
# Epoch 44/50
# 200/199 [==============================] - 73s 366ms/step - loss: 1.2977 - categorical_accuracy: 0.5507 - val_loss: 1.5259 - val_categorical_accuracy: 0.5312
# Epoch 45/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.3180 - categorical_accuracy: 0.5476 - val_loss: 1.6256 - val_categorical_accuracy: 0.4750
# Epoch 46/50
# 200/199 [==============================] - 73s 365ms/step - loss: 1.3123 - categorical_accuracy: 0.5492 - val_loss: 1.7071 - val_categorical_accuracy: 0.4800
# Epoch 47/50
# 200/199 [==============================] - 73s 365ms/step - loss: 1.2903 - categorical_accuracy: 0.5617 - val_loss: 1.6193 - val_categorical_accuracy: 0.4975
# Epoch 48/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.2694 - categorical_accuracy: 0.5626 - val_loss: 1.5562 - val_categorical_accuracy: 0.5200
# Epoch 49/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.2755 - categorical_accuracy: 0.5620 - val_loss: 1.5778 - val_categorical_accuracy: 0.5013
# Epoch 50/50
# 200/199 [==============================] - 73s 366ms/step - loss: 1.2455 - categorical_accuracy: 0.5696 - val_loss: 1.6247 - val_categorical_accuracy: 0.4925
# Train:
# [1.341331589421351, 0.5479130744934082]
# Val:
# [1.4297495007514953, 0.5362499952316284]

# %%
model = keras.Sequential()

model.add(vgg_conv)
model.add(Flatten())
model.add(Dense(8, activation='relu', kernel_regularizer=keras.regularizers.l2()))
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(lr=0.0001), metrics=['categorical_accuracy'])

mcp_save = ModelCheckpoint('retrained-model-mel-spec.hdf5', save_best_only=True, monitor='val_categorical_accuracy', mode='max', verbose=0)
history = model.fit(train_generator, steps_per_epoch=len(X_train)/ train_batchsize, epochs=50, validation_data=(X_val_RGB, y_val), callbacks=[mcp_save])
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

model = load_model('retrained-model-mel-spec.hdf5')
print('Train:')
print(model.evaluate(X_train_RGB, y_train, verbose=2))
print('Val:')
print(model.evaluate(X_val_RGB, y_val, verbose=2))
# Out:
# Epoch 1/50
# 200/199 [==============================] - 76s 379ms/step - loss: 1.9261 - categorical_accuracy: 0.2806 - val_loss: 1.8661 - val_categorical_accuracy: 0.3525
# Epoch 2/50
# 200/199 [==============================] - 74s 369ms/step - loss: 1.7916 - categorical_accuracy: 0.3175 - val_loss: 1.9135 - val_categorical_accuracy: 0.3438
# Epoch 3/50
# 200/199 [==============================] - 73s 366ms/step - loss: 1.7658 - categorical_accuracy: 0.3334 - val_loss: 1.8266 - val_categorical_accuracy: 0.3413
# Epoch 4/50
# 200/199 [==============================] - 74s 369ms/step - loss: 1.7356 - categorical_accuracy: 0.3474 - val_loss: 1.8658 - val_categorical_accuracy: 0.3338
# Epoch 5/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.7127 - categorical_accuracy: 0.3528 - val_loss: 1.8945 - val_categorical_accuracy: 0.3425
# Epoch 6/50
# 200/199 [==============================] - 74s 370ms/step - loss: 1.6857 - categorical_accuracy: 0.3650 - val_loss: 1.8653 - val_categorical_accuracy: 0.3487
# Epoch 7/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.6619 - categorical_accuracy: 0.3720 - val_loss: 1.8881 - val_categorical_accuracy: 0.3550
# Epoch 8/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.6483 - categorical_accuracy: 0.3756 - val_loss: 1.9365 - val_categorical_accuracy: 0.3738
# Epoch 9/50
# 200/199 [==============================] - 73s 366ms/step - loss: 1.6299 - categorical_accuracy: 0.3922 - val_loss: 1.8390 - val_categorical_accuracy: 0.3988
# Epoch 10/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.6049 - categorical_accuracy: 0.3950 - val_loss: 1.8146 - val_categorical_accuracy: 0.4525
# Epoch 11/50
# 200/199 [==============================] - 74s 371ms/step - loss: 1.5887 - categorical_accuracy: 0.4135 - val_loss: 1.8581 - val_categorical_accuracy: 0.4425
# Epoch 12/50
# 200/199 [==============================] - 74s 369ms/step - loss: 1.5510 - categorical_accuracy: 0.4221 - val_loss: 1.7653 - val_categorical_accuracy: 0.5038
# Epoch 13/50
# 200/199 [==============================] - 74s 369ms/step - loss: 1.5526 - categorical_accuracy: 0.4415 - val_loss: 1.8018 - val_categorical_accuracy: 0.4900
# Epoch 14/50
# 200/199 [==============================] - 74s 369ms/step - loss: 1.5254 - categorical_accuracy: 0.4680 - val_loss: 1.7934 - val_categorical_accuracy: 0.4487
# Epoch 15/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.5152 - categorical_accuracy: 0.4654 - val_loss: 1.7515 - val_categorical_accuracy: 0.4988
# Epoch 16/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.4943 - categorical_accuracy: 0.4716 - val_loss: 1.6992 - val_categorical_accuracy: 0.5150
# Epoch 17/50
# 200/199 [==============================] - 74s 369ms/step - loss: 1.4831 - categorical_accuracy: 0.4726 - val_loss: 1.7520 - val_categorical_accuracy: 0.4550
# Epoch 18/50
# 200/199 [==============================] - 75s 377ms/step - loss: 1.4552 - categorical_accuracy: 0.4898 - val_loss: 1.8155 - val_categorical_accuracy: 0.4750
# Epoch 19/50
# 200/199 [==============================] - 74s 369ms/step - loss: 1.4268 - categorical_accuracy: 0.5084 - val_loss: 1.8437 - val_categorical_accuracy: 0.4675
# Epoch 20/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.4407 - categorical_accuracy: 0.4930 - val_loss: 1.8392 - val_categorical_accuracy: 0.4650
# Epoch 21/50
# 200/199 [==============================] - 74s 370ms/step - loss: 1.4236 - categorical_accuracy: 0.4991 - val_loss: 1.8174 - val_categorical_accuracy: 0.4850
# Epoch 22/50
# 200/199 [==============================] - 74s 371ms/step - loss: 1.4024 - categorical_accuracy: 0.5132 - val_loss: 1.8056 - val_categorical_accuracy: 0.4900
# Epoch 23/50
# 200/199 [==============================] - 74s 370ms/step - loss: 1.4065 - categorical_accuracy: 0.5091 - val_loss: 1.7769 - val_categorical_accuracy: 0.5138
# Epoch 24/50
# 200/199 [==============================] - 74s 370ms/step - loss: 1.4004 - categorical_accuracy: 0.5068 - val_loss: 1.7258 - val_categorical_accuracy: 0.4988
# Epoch 25/50
# 200/199 [==============================] - 74s 370ms/step - loss: 1.3781 - categorical_accuracy: 0.5207 - val_loss: 1.7903 - val_categorical_accuracy: 0.4663
# Epoch 26/50
# 200/199 [==============================] - 74s 370ms/step - loss: 1.3626 - categorical_accuracy: 0.5260 - val_loss: 1.8070 - val_categorical_accuracy: 0.4762
# Epoch 27/50
# 200/199 [==============================] - 74s 370ms/step - loss: 1.3612 - categorical_accuracy: 0.5213 - val_loss: 1.7800 - val_categorical_accuracy: 0.4963
# Epoch 28/50
# 200/199 [==============================] - 73s 367ms/step - loss: 1.3630 - categorical_accuracy: 0.5170 - val_loss: 1.7692 - val_categorical_accuracy: 0.4963
# Epoch 29/50
# 200/199 [==============================] - 74s 370ms/step - loss: 1.3412 - categorical_accuracy: 0.5256 - val_loss: 1.7593 - val_categorical_accuracy: 0.4638
# Epoch 30/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.3387 - categorical_accuracy: 0.5331 - val_loss: 1.7762 - val_categorical_accuracy: 0.4875
# Epoch 31/50
# 200/199 [==============================] - 73s 365ms/step - loss: 1.3287 - categorical_accuracy: 0.5342 - val_loss: 1.8726 - val_categorical_accuracy: 0.4700
# Epoch 32/50
# 200/199 [==============================] - 73s 366ms/step - loss: 1.3022 - categorical_accuracy: 0.5398 - val_loss: 1.9509 - val_categorical_accuracy: 0.4475
# Epoch 33/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.3237 - categorical_accuracy: 0.5279 - val_loss: 1.8776 - val_categorical_accuracy: 0.4975
# Epoch 34/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.3027 - categorical_accuracy: 0.5434 - val_loss: 1.9765 - val_categorical_accuracy: 0.4712
# Epoch 35/50
# 200/199 [==============================] - 74s 369ms/step - loss: 1.2841 - categorical_accuracy: 0.5474 - val_loss: 1.9662 - val_categorical_accuracy: 0.4688
# Epoch 36/50
# 200/199 [==============================] - 74s 370ms/step - loss: 1.2698 - categorical_accuracy: 0.5564 - val_loss: 1.9290 - val_categorical_accuracy: 0.4888
# Epoch 37/50
# 200/199 [==============================] - 73s 366ms/step - loss: 1.3022 - categorical_accuracy: 0.5473 - val_loss: 1.8345 - val_categorical_accuracy: 0.4888
# Epoch 38/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.2803 - categorical_accuracy: 0.5509 - val_loss: 1.8301 - val_categorical_accuracy: 0.4975
# Epoch 39/50
# 200/199 [==============================] - 74s 369ms/step - loss: 1.2564 - categorical_accuracy: 0.5590 - val_loss: 1.9292 - val_categorical_accuracy: 0.4762
# Epoch 40/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.2571 - categorical_accuracy: 0.5565 - val_loss: 1.9746 - val_categorical_accuracy: 0.4675
# Epoch 41/50
# 200/199 [==============================] - 74s 370ms/step - loss: 1.2333 - categorical_accuracy: 0.5654 - val_loss: 2.0589 - val_categorical_accuracy: 0.4863
# Epoch 42/50
# 200/199 [==============================] - 74s 368ms/step - loss: 1.2135 - categorical_accuracy: 0.5682 - val_loss: 2.0976 - val_categorical_accuracy: 0.4850
# Epoch 43/50
# 200/199 [==============================] - 74s 369ms/step - loss: 1.2326 - categorical_accuracy: 0.5698 - val_loss: 1.8657 - val_categorical_accuracy: 0.4875
# Epoch 44/50
# 173/199 [========================>.....] - ETA: 9s - loss: 1.2150 - categorical_accuracy: 0.5691
