# %%
import numpy as np
import pandas as pd
import os
from os.path import isfile
import pickle
import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import keras
from keras.models import load_model
from keras.models import Sequential, Model
from keras.layers import Input, Dense, TimeDistributed, LSTM, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, Flatten, Conv2D, BatchNormalization, Lambda
from keras.layers.advanced_activations import ELU
from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras import backend
from keras.utils import np_utils
from keras.optimizers import Adam, RMSprop
from keras import regularizers

# %% [markdown]
# ### Load training and validation arrays

# %%
dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 
               'Instrumental':4,'International':5, 'Pop':6, 'Rock':7  }

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 2: 'Folk', 3: 'Hip-Hop', 4: 'Instrumental', 5: 'International', 6: 'Pop', 7: 'Rock'}

# %%
npzfile = np.load('shuffled_train.npz')
print(npzfile.files)
X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394, 8)

# %%
npzfile = np.load('shuffled_valid.npz')
print(npzfile.files)
X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800, 8)

# %% [markdown]
# ### Check by plotting a Spectrogram

# %%
num = 5288
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize = (10, 5))
librosa.display.specshow(spectogram.T, y_axis = 'mel', x_axis = 'time')
plt.colorbar(format = '%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Electronic

# %% [markdown]
# ### CRNN Model

# %%
batch_size = 32
num_classes = 8
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
N_LAYERS = 3
FILTER_LENGTH = 5
CONV_FILTER_COUNT = 56
BATCH_SIZE = 32
LSTM_COUNT = 96
EPOCH_COUNT = 70
NUM_HIDDEN = 64
L2_regularization = 0.001

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    # 3 1D Convolution Layers
    for i in range(N_LAYERS):
        # give name to the layers
        layer = Conv1D(
                filters = CONV_FILTER_COUNT,
                kernel_size = FILTER_LENGTH,
                kernel_regularizer = regularizers.l2(L2_regularization),  # Tried 0.001
                name = 'convolution_' + str(i + 1)
            )(layer)
        layer = BatchNormalization(momentum = 0.9)(layer)
        layer = Activation('relu')(layer)
        layer = MaxPooling1D(2)(layer)
        layer = Dropout(0.4)(layer)
    
    # LSTM Layer
    layer = LSTM(LSTM_COUNT, return_sequences = False)(layer)
    layer = Dropout(0.4)(layer)
    
    # Dense Layer
    layer = Dense(NUM_HIDDEN, kernel_regularizer = regularizers.l2(L2_regularization), name = 'dense1')(layer)
    layer = Dropout(0.4)(layer)
    
    # Softmax Output
    layer = Dense(num_classes)(layer)
    layer = Activation('softmax', name = 'output_realtime')(layer)
    model_output = layer
    model = Model(model_input, model_output)
    
    
    opt = Adam(lr=0.001)
    model.compile(
            loss = 'categorical_crossentropy',
            optimizer = opt,
            metrics = ['accuracy']
        )
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val):
    
    n_features = x_train.shape[2]
    input_shape = (None, n_features)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)

    checkpoint_callback = ModelCheckpoint('weights.best.h5', monitor = 'val_acc', verbose = 1,
                                          save_best_only = True, mode = 'max')    
    
    reducelr_callback = ReduceLROnPlateau(
                monitor = 'val_acc', factor = 0.5, patience = 10, min_delta = 0.01,
                verbose = 1
            )
    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size = BATCH_SIZE, epochs = EPOCH_COUNT,
                        validation_data = (x_val, y_val), verbose=1, callbacks = callbacks_list)

    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc = 'upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc = 'upper left')
    plt.show()

# %%
model, history  = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# Building model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, None, 128)         0
# _________________________________________________________________
# convolution_1 (Conv1D)       (None, None, 56)          35896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_7 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_2 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_8 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_8 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_3 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_9 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_9 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 96)                58752
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 96)                0
# _________________________________________________________________
# dense1 (Dense)               (None, 64)                6208
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 520
# _________________________________________________________________
# output_realtime (Activation) (None, 8)                 0
# =================================================================
# Total params: 133,520
# Trainable params: 133,184
# Non-trainable params: 336
# _________________________________________________________________
# None
# Training...
# Train on 6394 samples, validate on 800 samples
# Epoch 1/70
# 6394/6394 [==============================] - 38s 6ms/step - loss: 2.1449 - acc: 0.2815 - val_loss: 2.1704 - val_acc: 0.2750
#
# Epoch 00001: val_acc improved from -inf to 0.27500, saving model to weights.best.h5
# Epoch 2/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.9955 - acc: 0.3539 - val_loss: 2.2493 - val_acc: 0.1950
#
# Epoch 00002: val_acc did not improve from 0.27500
# Epoch 3/70
# 6394/6394 [==============================] - 34s 5ms/step - loss: 1.9250 - acc: 0.3713 - val_loss: 2.3402 - val_acc: 0.2175
#
# Epoch 00003: val_acc did not improve from 0.27500
# Epoch 4/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.8835 - acc: 0.3855 - val_loss: 1.9732 - val_acc: 0.3075
#
# Epoch 00004: val_acc improved from 0.27500 to 0.30750, saving model to weights.best.h5
# Epoch 5/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.8419 - acc: 0.4104 - val_loss: 2.4030 - val_acc: 0.2225
#
# Epoch 00005: val_acc did not improve from 0.30750
# Epoch 6/70
# 6394/6394 [==============================] - 34s 5ms/step - loss: 1.7991 - acc: 0.4168 - val_loss: 2.7530 - val_acc: 0.1638
#
# Epoch 00006: val_acc did not improve from 0.30750
# Epoch 7/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.7632 - acc: 0.4301 - val_loss: 2.4228 - val_acc: 0.2487
#
# Epoch 00007: val_acc did not improve from 0.30750
# Epoch 8/70
# 6394/6394 [==============================] - 35s 6ms/step - loss: 1.7593 - acc: 0.4331 - val_loss: 2.1948 - val_acc: 0.2662
#
# Epoch 00008: val_acc did not improve from 0.30750
# Epoch 9/70
# 6394/6394 [==============================] - 38s 6ms/step - loss: 1.7286 - acc: 0.4407 - val_loss: 1.8438 - val_acc: 0.3950
#
# Epoch 00009: val_acc improved from 0.30750 to 0.39500, saving model to weights.best.h5
# Epoch 10/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.7018 - acc: 0.4515 - val_loss: 1.8520 - val_acc: 0.3637
#
# Epoch 00010: val_acc did not improve from 0.39500
# Epoch 11/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.6794 - acc: 0.4642 - val_loss: 2.1497 - val_acc: 0.2550
#
# Epoch 00011: val_acc did not improve from 0.39500
# Epoch 12/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.6593 - acc: 0.4736 - val_loss: 2.0780 - val_acc: 0.3013
#
# Epoch 00012: val_acc did not improve from 0.39500
# Epoch 13/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.6329 - acc: 0.4809 - val_loss: 1.9429 - val_acc: 0.3163
#
# Epoch 00013: val_acc did not improve from 0.39500
# Epoch 14/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.6344 - acc: 0.4787 - val_loss: 2.0427 - val_acc: 0.3150
#
# Epoch 00014: val_acc did not improve from 0.39500
# Epoch 15/70
# 6394/6394 [==============================] - 38s 6ms/step - loss: 1.6012 - acc: 0.4900 - val_loss: 1.8586 - val_acc: 0.3475
#
# Epoch 00015: val_acc did not improve from 0.39500
# Epoch 16/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.5885 - acc: 0.4919 - val_loss: 2.2101 - val_acc: 0.2600
#
# Epoch 00016: val_acc did not improve from 0.39500
# Epoch 17/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.5888 - acc: 0.4909 - val_loss: 1.9920 - val_acc: 0.2950
#
# Epoch 00017: val_acc did not improve from 0.39500
# Epoch 18/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.5948 - acc: 0.4887 - val_loss: 2.0820 - val_acc: 0.3238
#
# Epoch 00018: val_acc did not improve from 0.39500
# Epoch 19/70
# 6394/6394 [==============================] - 35s 6ms/step - loss: 1.5656 - acc: 0.5005 - val_loss: 1.9325 - val_acc: 0.3688
#
# Epoch 00019: val_acc did not improve from 0.39500
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/70
# 6394/6394 [==============================] - 35s 6ms/step - loss: 1.4952 - acc: 0.5307 - val_loss: 1.7618 - val_acc: 0.3825
#
# Epoch 00020: val_acc did not improve from 0.39500
# Epoch 21/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.4787 - acc: 0.5305 - val_loss: 1.8624 - val_acc: 0.3912
#
# Epoch 00021: val_acc did not improve from 0.39500
# Epoch 22/70
# 6394/6394 [==============================] - 35s 6ms/step - loss: 1.4559 - acc: 0.5407 - val_loss: 1.8870 - val_acc: 0.3637
#
# Epoch 00022: val_acc did not improve from 0.39500
# Epoch 23/70
# 6394/6394 [==============================] - 38s 6ms/step - loss: 1.4488 - acc: 0.5416 - val_loss: 2.5442 - val_acc: 0.2400
#
# Epoch 00023: val_acc did not improve from 0.39500
# Epoch 24/70
# 6394/6394 [==============================] - 37s 6ms/step - loss: 1.4422 - acc: 0.5452 - val_loss: 2.1396 - val_acc: 0.3050
#
# Epoch 00024: val_acc did not improve from 0.39500
# Epoch 25/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.4332 - acc: 0.5444 - val_loss: 1.6289 - val_acc: 0.4350
#
# Epoch 00025: val_acc improved from 0.39500 to 0.43500, saving model to weights.best.h5
# Epoch 26/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.4076 - acc: 0.5660 - val_loss: 1.9681 - val_acc: 0.3475
#
# Epoch 00026: val_acc did not improve from 0.43500
# Epoch 27/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.4069 - acc: 0.5561 - val_loss: 1.6895 - val_acc: 0.4375
#
# Epoch 00027: val_acc improved from 0.43500 to 0.43750, saving model to weights.best.h5
# Epoch 28/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.4170 - acc: 0.5513 - val_loss: 1.7870 - val_acc: 0.3937
#
# Epoch 00028: val_acc did not improve from 0.43750
# Epoch 29/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.3898 - acc: 0.5635 - val_loss: 2.0448 - val_acc: 0.3887
#
# Epoch 00029: val_acc did not improve from 0.43750
# Epoch 30/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.3690 - acc: 0.5683 - val_loss: 2.3213 - val_acc: 0.3000
#
# Epoch 00030: val_acc did not improve from 0.43750
# Epoch 31/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.3708 - acc: 0.5730 - val_loss: 1.7575 - val_acc: 0.4275
#
# Epoch 00031: val_acc did not improve from 0.43750
# Epoch 32/70
# 6394/6394 [==============================] - 38s 6ms/step - loss: 1.3530 - acc: 0.5737 - val_loss: 1.5924 - val_acc: 0.4775
#
# Epoch 00032: val_acc improved from 0.43750 to 0.47750, saving model to weights.best.h5
# Epoch 33/70
# 6394/6394 [==============================] - 35s 6ms/step - loss: 1.3588 - acc: 0.5713 - val_loss: 2.4271 - val_acc: 0.3663
#
# Epoch 00033: val_acc did not improve from 0.47750
# Epoch 34/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.3566 - acc: 0.5680 - val_loss: 1.8413 - val_acc: 0.4075
#
# Epoch 00034: val_acc did not improve from 0.47750
# Epoch 35/70
# 6394/6394 [==============================] - 38s 6ms/step - loss: 1.3316 - acc: 0.5815 - val_loss: 1.9062 - val_acc: 0.4062
#
# Epoch 00035: val_acc did not improve from 0.47750
# Epoch 36/70
# 6394/6394 [==============================] - 37s 6ms/step - loss: 1.3412 - acc: 0.5780 - val_loss: 3.4348 - val_acc: 0.2188
#
# Epoch 00036: val_acc did not improve from 0.47750
# Epoch 37/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.3532 - acc: 0.5762 - val_loss: 1.6432 - val_acc: 0.4512
#
# Epoch 00037: val_acc did not improve from 0.47750
# Epoch 38/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.3226 - acc: 0.5855 - val_loss: 1.9340 - val_acc: 0.3575
#
# Epoch 00038: val_acc did not improve from 0.47750
# Epoch 39/70
# 6394/6394 [==============================] - 38s 6ms/step - loss: 1.3206 - acc: 0.5890 - val_loss: 1.8361 - val_acc: 0.4012
#
# Epoch 00039: val_acc did not improve from 0.47750
# Epoch 40/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.3389 - acc: 0.5805 - val_loss: 2.9130 - val_acc: 0.2112
#
# Epoch 00040: val_acc did not improve from 0.47750
# Epoch 41/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.2861 - acc: 0.6040 - val_loss: 1.8964 - val_acc: 0.3912
#
# Epoch 00041: val_acc did not improve from 0.47750
# Epoch 42/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.3019 - acc: 0.5965 - val_loss: 1.8565 - val_acc: 0.3937
#
# Epoch 00042: val_acc did not improve from 0.47750
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 43/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.2527 - acc: 0.6082 - val_loss: 1.6716 - val_acc: 0.4562
#
# Epoch 00043: val_acc did not improve from 0.47750
# Epoch 44/70
# 6394/6394 [==============================] - 35s 6ms/step - loss: 1.2232 - acc: 0.6272 - val_loss: 1.5845 - val_acc: 0.5050
#
# Epoch 00044: val_acc improved from 0.47750 to 0.50500, saving model to weights.best.h5
# Epoch 45/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.2211 - acc: 0.6232 - val_loss: 1.6275 - val_acc: 0.4938
#
# Epoch 00045: val_acc did not improve from 0.50500
# Epoch 46/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.2244 - acc: 0.6231 - val_loss: 1.6327 - val_acc: 0.4625
#
# Epoch 00046: val_acc did not improve from 0.50500
# Epoch 47/70
# 6394/6394 [==============================] - 38s 6ms/step - loss: 1.2028 - acc: 0.6262 - val_loss: 1.8290 - val_acc: 0.4437
#
# Epoch 00047: val_acc did not improve from 0.50500
# Epoch 48/70
# 6394/6394 [==============================] - 37s 6ms/step - loss: 1.1894 - acc: 0.6328 - val_loss: 1.8418 - val_acc: 0.4325
#
# Epoch 00048: val_acc did not improve from 0.50500
# Epoch 49/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.1998 - acc: 0.6259 - val_loss: 2.0618 - val_acc: 0.4200
#
# Epoch 00049: val_acc did not improve from 0.50500
# Epoch 50/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.1766 - acc: 0.6378 - val_loss: 1.8137 - val_acc: 0.4300
#
# Epoch 00050: val_acc did not improve from 0.50500
# Epoch 51/70
# 6394/6394 [==============================] - 35s 6ms/step - loss: 1.1794 - acc: 0.6336 - val_loss: 1.6893 - val_acc: 0.4950
#
# Epoch 00051: val_acc did not improve from 0.50500
# Epoch 52/70
# 6394/6394 [==============================] - 38s 6ms/step - loss: 1.1726 - acc: 0.6395 - val_loss: 1.7283 - val_acc: 0.4300
#
# Epoch 00052: val_acc did not improve from 0.50500
# Epoch 53/70
# 6394/6394 [==============================] - 38s 6ms/step - loss: 1.1672 - acc: 0.6409 - val_loss: 1.7793 - val_acc: 0.4238
#
# Epoch 00053: val_acc did not improve from 0.50500
# Epoch 54/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.1592 - acc: 0.6379 - val_loss: 1.6356 - val_acc: 0.4713
#
# Epoch 00054: val_acc did not improve from 0.50500
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 55/70
# 6394/6394 [==============================] - 37s 6ms/step - loss: 1.1416 - acc: 0.6472 - val_loss: 1.5614 - val_acc: 0.4975
#
# Epoch 00055: val_acc did not improve from 0.50500
# Epoch 56/70
# 6394/6394 [==============================] - 37s 6ms/step - loss: 1.1320 - acc: 0.6484 - val_loss: 1.6493 - val_acc: 0.4750
#
# Epoch 00056: val_acc did not improve from 0.50500
# Epoch 57/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.1225 - acc: 0.6647 - val_loss: 1.7444 - val_acc: 0.4625
#
# Epoch 00057: val_acc did not improve from 0.50500
# Epoch 58/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.1206 - acc: 0.6553 - val_loss: 1.6332 - val_acc: 0.4863
#
# Epoch 00058: val_acc did not improve from 0.50500
# Epoch 59/70
# 6394/6394 [==============================] - 39s 6ms/step - loss: 1.1107 - acc: 0.6581 - val_loss: 1.5269 - val_acc: 0.5162
#
# Epoch 00059: val_acc improved from 0.50500 to 0.51625, saving model to weights.best.h5
# Epoch 60/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.0985 - acc: 0.6637 - val_loss: 1.7585 - val_acc: 0.4738
#
# Epoch 00060: val_acc did not improve from 0.51625
# Epoch 61/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.1077 - acc: 0.6603 - val_loss: 1.7083 - val_acc: 0.4900
#
# Epoch 00061: val_acc did not improve from 0.51625
# Epoch 62/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.0992 - acc: 0.6652 - val_loss: 1.8690 - val_acc: 0.4700
#
# Epoch 00062: val_acc did not improve from 0.51625
# Epoch 63/70
# 6394/6394 [==============================] - 35s 6ms/step - loss: 1.0944 - acc: 0.6655 - val_loss: 1.7830 - val_acc: 0.4637
#
# Epoch 00063: val_acc did not improve from 0.51625
# Epoch 64/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.0929 - acc: 0.6653 - val_loss: 1.5957 - val_acc: 0.5075
#
# Epoch 00064: val_acc did not improve from 0.51625
# Epoch 65/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.0805 - acc: 0.6652 - val_loss: 1.6022 - val_acc: 0.5062
#
# Epoch 00065: val_acc did not improve from 0.51625
# Epoch 66/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.0805 - acc: 0.6678 - val_loss: 1.5623 - val_acc: 0.5038
#
# Epoch 00066: val_acc did not improve from 0.51625
# Epoch 67/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.0839 - acc: 0.6652 - val_loss: 1.6568 - val_acc: 0.5150
#
# Epoch 00067: val_acc did not improve from 0.51625
# Epoch 68/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.0758 - acc: 0.6719 - val_loss: 1.6499 - val_acc: 0.4875
#
# Epoch 00068: val_acc did not improve from 0.51625
# Epoch 69/70
# 6394/6394 [==============================] - 36s 6ms/step - loss: 1.0797 - acc: 0.6714 - val_loss: 1.6234 - val_acc: 0.5150
#
# Epoch 00069: val_acc did not improve from 0.51625
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 70/70
# 6394/6394 [==============================] - 35s 5ms/step - loss: 1.0474 - acc: 0.6747 - val_loss: 1.6458 - val_acc: 0.5100
#
# Epoch 00070: val_acc did not improve from 0.51625

# %%
show_summary_stats(history)
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc', 'lr'])

# %%
y_true = np.argmax(y_valid, axis = 1)
y_pred = model.predict(X_valid)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.44      0.51      0.47       100
#  Experimental       0.47      0.43      0.45       100
#          Folk       0.65      0.72      0.69       100
#       Hip-Hop       0.59      0.69      0.64       100
#  Instrumental       0.51      0.42      0.46       100
# International       0.52      0.65      0.58       100
#           Pop       0.08      0.05      0.06       100
#          Rock       0.64      0.64      0.64       100
#
#      accuracy                           0.51       800
#     macro avg       0.49      0.51      0.50       800
#  weighted avg       0.49      0.51      0.50       800

# %%
print(accuracy_score(y_true, y_pred))
# Out:
# 0.51375

# %% [markdown]
# ### Connect to Test Set

# %%
weights_path = 'weights.best.h5'
model = load_model(weights_path)

# %%
npzfile = np.load('test_arr.npz')
print(npzfile.files)
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_test -= 1
print(np.amin(y_test), np.amax(y_test), np.mean(y_test))
# Out:
# 0 7 3.5

# %%
X_test_raw = librosa.core.db_to_power(X_test, ref = 1.0)
print(np.amin(X_test_raw), np.amax(X_test_raw), np.mean(X_test_raw))
# Out:
# 1e-08 1.0000000000000016 0.004623813018385694

# %%
X_test = np.log(X_test_raw)

y_true = y_test
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names = target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.64      0.49      0.55       100
#  Experimental       0.28      0.22      0.25       100
#          Folk       0.19      0.16      0.17       100
#       Hip-Hop       0.57      0.85      0.68       100
#  Instrumental       0.36      0.34      0.35       100
# International       0.46      0.64      0.54       100
#           Pop       0.30      0.27      0.28       100
#          Rock       0.64      0.56      0.60       100
#
#      accuracy                           0.44       800
#     macro avg       0.43      0.44      0.43       800
#  weighted avg       0.43      0.44      0.43       800

# %%
print(accuracy_score(y_true, y_pred))
# Out:
# 0.44125

# %%
mat = confusion_matrix(y_true, y_pred)
sns.heatmap(mat.T, square = True, annot = True, fmt = 'd', cbar = False,
            xticklabels = dict_genres.keys(),
            yticklabels = dict_genres.keys())
plt.xlabel('true label')
plt.ylabel('predicted label');
